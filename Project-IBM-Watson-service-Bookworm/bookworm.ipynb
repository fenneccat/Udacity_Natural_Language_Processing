# %% [markdown]
# # Bookworm
#
#
# ## Overview
#
# In this project, you will build a simple question-answering agent that is able to learn from any text data you provide, and answer queries posed in natural language. You will use IBM Watson's cloud-based services to process the input text data and find relevant responses.
#
# ## Learning Objectives
#
# By completing this project, you will learn how to:
#
# - Create a cloud-based NLP service instance and configure it.
# - Ingest a set of text documents using the service and analyze the results.
# - Accept questions in natural language and parse them.
# - Find relevant answers from the preprocessed text data.
#
# ## Getting Started
#
# In order to use Watson's cloud-based services, you first need to create an account on the [IBM Bluemix platform](https://console.ng.bluemix.net/).
#
# <div>
#     <div style="display: table-cell; width: 50%;">
#         <img src="images/watson-logo.png" alt="IBM Watson logo" width="200" />
#     </div>
#     <div style="display: table-cell; width: 50%;">
#         <img src="images/bluemix-logo.png" alt="IBM Bluemix logo" width="400" />
#     </div>
# </div>
#
# Then, for each service you want to use, you have to create an instance of that service. You can continue with the tasks below, and create a service instance when indicated.

# %% [markdown]
# ## 1. Create and configure Discovery service
#
# Create an instance of the **Discovery** service. You will use this to process a set of text documents, and _discover_ relevant facts and relationships.
#
# - Go to the [IBM Bluemix Catalog](https://console.bluemix.net/catalog/).
# - Select [Discovery](https://console.bluemix.net/catalog/services/discovery) service under the [AI](https://console.bluemix.net/catalog/?category=ai) category.
# - Enter a Service Name for that instance, e.g. `Discovery-Bookworm` and click **`Create`** button on the bottom right hand corner of the screen.
# - You should be able to see your newly-created service in your [Bluemix Apps Dashboard](https://console.bluemix.net/dashboard/apps).
# <img src="images/app-dashboard-discovery.png" alt="App Dashboard" width="800" />
#
# - Open the `Discovery-Bookworm` service instance and find your `Url` and `API Key` in **Credentials** section.
#
# <img src="images/discovery-apikey.png" alt="Discovery Service - Credentials tab" width="800" />
#
# _Note: you will need the username and password when connecting to the service in the next steps shortly._

# %% [markdown]
# ### Connect to the service instance
#
# Let's connect to the service instance you just created using IBM Watson's [Python SDK](https://github.com/watson-developer-cloud/python-sdk). You will first need to install the SDK:
# ```bash
# pip install watson-developer-cloud
# ```
#
# Now execute each code cell below using **`Shift+Enter`**, and complete any steps indicated by a **`TODO`** comment. For more information on the Discovery service, please read the [Documentation](https://www.ibm.com/watson/developercloud/doc/discovery/index.html) and look at the [API Reference](https://www.ibm.com/watson/developercloud/discovery/api/v1/?python) as needed.

# %%
# Install watson-developer-cloud
# This takes about a minute

# !pip install --upgrade "watson-developer-cloud>=2.4.1"
# Out:
# Collecting watson-developer-cloud>=2.4.1
#   Downloading https://files.pythonhosted.org/packages/fc/a5/a89fc49bd82eb6ea569e45b43383c28cd51b5076f43010dcc3331c137ff5/watson-developer-cloud-2.10.1.tar.gz (248kB)
#     100% |████████████████████████████████| 256kB 4.8MB/s ta 0:00:01
# Requirement already satisfied, skipping upgrade: requests<3.0,>=2.0 in /opt/conda/lib/python3.6/site-packages (from watson-developer-cloud>=2.4.1) (2.18.4)
# Requirement already satisfied, skipping upgrade: python_dateutil>=2.5.3 in /opt/conda/lib/python3.6/site-packages (from watson-developer-cloud>=2.4.1) (2.6.1)
# Collecting websocket-client==0.48.0 (from watson-developer-cloud>=2.4.1)
#   Downloading https://files.pythonhosted.org/packages/8a/a1/72ef9aa26cfe1a75cee09fc1957e4723add9de098c15719416a1ee89386b/websocket_client-0.48.0-py2.py3-none-any.whl (198kB)
#     100% |████████████████████████████████| 204kB 6.7MB/s ta 0:00:01
# Requirement already satisfied, skipping upgrade: chardet<3.1.0,>=3.0.2 in /opt/conda/lib/python3.6/site-packages (from requests<3.0,>=2.0->watson-developer-cloud>=2.4.1) (3.0.4)
# Requirement already satisfied, skipping upgrade: idna<2.7,>=2.5 in /opt/conda/lib/python3.6/site-packages (from requests<3.0,>=2.0->watson-developer-cloud>=2.4.1) (2.6)
# Requirement already satisfied, skipping upgrade: urllib3<1.23,>=1.21.1 in /opt/conda/lib/python3.6/site-packages (from requests<3.0,>=2.0->watson-developer-cloud>=2.4.1) (1.22)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /opt/conda/lib/python3.6/site-packages (from requests<3.0,>=2.0->watson-developer-cloud>=2.4.1) (2019.11.28)
# Requirement already satisfied, skipping upgrade: six>=1.5 in /opt/conda/lib/python3.6/site-packages (from python_dateutil>=2.5.3->watson-developer-cloud>=2.4.1) (1.11.0)
# Building wheels for collected packages: watson-developer-cloud
#   Running setup.py bdist_wheel for watson-developer-cloud ... done
#   Stored in directory: /root/.cache/pip/wheels/ea/a7/19/fac0a408a586265eb374005308a7553d4494ab41b2fd88f5bc
# Successfully built watson-developer-cloud
# Installing collected packages: websocket-client, watson-developer-cloud
# Successfully installed watson-developer-cloud-2.10.1 websocket-client-0.48.0

# %%
# Usual Python imports
import sys
import os
import glob
import json

# BeautifulSoup, for parsing HTML
from bs4 import BeautifulSoup

# Matplotlib, for plotting
import matplotlib.pyplot as plt
# %matplotlib inline

# Watson Python SDK
# If not installed run: 
# !pip install --upgrade watson-developer-cloud
import watson_developer_cloud

# Utility functions
# %load_ext autoreload
# %aimport helper
# %autoreload 1

# %% [markdown]
# ###  Using the Service Credentials
#
# Before you can connect to Watson Service, you need to copy and paste `Username` and `Password` credentials from Bluemix Service console to this notebook.
# _Note: these credentials are different from your IBM Bluemix login, and are specific to the service instance._
#
# 1. Open `service-credentials.json` file:
#     * from this Jupyter Notebook top navigation, click `File` &rarr; `Open` &rarr; `service-credentials.json`
# 2. Copy your `API Key` and `Url` from Discovery service console.
# 3. Paste the credentials into `apikey` and `url` values in `Discovery` object.
#
#
# <img src="images/service-discovery-json.png" alt="Discovery Service - Credentials JSON" width="600" />

# %%
discovery_creds = helper.fetch_credentials('discovery')

discovery = watson_developer_cloud.DiscoveryV1(
                        version='2018-08-01',
                        url=discovery_creds['url'],
                        iam_apikey=discovery_creds['apikey'])
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:6: DeprecationWarning: watson-developer-cloud moved to ibm-watson. To get updates, use the new package.

# %% [markdown]
# ### Create an environment
#
# The Discovery service organizes everything needed for a particular application in an [_environment_](https://www.ibm.com/watson/developercloud/discovery/api/v1/curl.html?curl#environments-api). An environment must be created before collections of private data can be created.
#
# Let's create one called `Bookworm` for this project.
#
# > _**Note**: It is okay to run this block multiple times - it will not create duplicate environments with the same name._

# %%
# Prepare an environment to work in
env, env_id = helper.fetch_object(
    discovery, "environment", "Bookworm",
    create=True, create_args=dict(
        description="A space to read and understand stories"  # feel free to edit
    ))
# Out:
# {'description': 'A space to read and understand stories', 'name': 'Bookworm'}
# Created environment: Bookworm (298e5cb9-1f37-4f63-bbb6-14217fdcc403)

# %% [markdown]
# ### Verify configuration options
#
# A [_configuration_](https://www.ibm.com/watson/developercloud/discovery/api/v1/curl.html?curl#configurations-api) defines what natural language processing routines are applied to any documents that are submitted to the service. Each environment gets a default configuration when it is created.
#
# You can fetch the default configuration and view the different options using the following piece of code.

# %%
# Lists existing configurations for the service instance and store default configuration id
configurations = discovery.list_configurations(environment_id=env_id).get_result()
cfg_id =  configurations['configurations'][0]['configuration_id']
print(json.dumps(configurations, indent=2))
# Out:
# {
#   "configurations": [
#     {
#       "configuration_id": "3ffef54c-e190-4386-b5dc-3428e50fa1ad",
#       "name": "Default Configuration",
#       "description": "The configuration used by default when creating a new collection without specifying a configuration_id.",
#       "created": "2020-05-25T05:05:53.213Z",
#       "updated": "2020-05-25T05:05:53.213Z"
#     }
#   ]
# }

# %%
# Get default configuration details
config = discovery.get_configuration(environment_id=env_id, configuration_id=cfg_id).get_result()
print(json.dumps(config, indent=2))
# Out:
# {
#   "configuration_id": "3ffef54c-e190-4386-b5dc-3428e50fa1ad",
#   "name": "Default Configuration",
#   "created": "2020-05-25T05:05:53.213Z",
#   "updated": "2020-05-25T05:05:53.213Z",
#   "description": "The configuration used by default when creating a new collection without specifying a configuration_id.",
#   "conversions": {
#     "html": {
#       "exclude_content": {
#         "xpaths": []
#       },
#       "exclude_tag_attributes": [
#         "EVENT_ACTIONS"
#       ],
#       "exclude_tags_completely": [
#         "script",
#         "sup"
#       ],
#       "exclude_tags_keep_content": [
#         "font",
#         "em",
#         "span"
#       ],
#       "keep_content": {
#         "xpaths": []
#       }
#     },
#     "json_normalizations": [],
#     "pdf": {
#       "heading": {
#         "fonts": [
#           {
#             "level": 1,
#             "max_size": 80,
#             "min_size": 24
#           },
#           {
#             "bold": false,
#             "italic": false,
#             "level": 2,
#             "max_size": 24,
#             "min_size": 18
#           },
#           {
#             "bold": true,
#             "level": 2,
#             "max_size": 24,
#             "min_size": 18
#           },
#           {
#             "bold": false,
#             "italic": false,
#             "level": 3,
#             "max_size": 18,
#             "min_size": 13
#           },
#           {
#             "bold": true,
#             "level": 3,
#             "max_size": 18,
#             "min_size": 13
#           },
#           {
#             "bold": false,
#             "italic": false,
#             "level": 4,
#             "max_size": 13,
#             "min_size": 11
#           }
#         ]
#       }
#     },
#     "word": {
#       "heading": {
#         "fonts": [
#           {
#             "bold": false,
#             "italic": false,
#             "level": 1,
#             "min_size": 24
#           },
#           {
#             "bold": true,
#             "italic": false,
#             "level": 2,
#             "max_size": 23,
#             "min_size": 18
#           },
#           {
#             "bold": false,
#             "italic": false,
#             "level": 3,
#             "max_size": 17,
#             "min_size": 14
#           },
#           {
#             "bold": true,
#             "italic": false,
#             "level": 4,
#             "max_size": 13,
#             "min_size": 13
#           }
#         ],
#         "styles": [
#           {
#             "level": 1,
#             "names": [
#               "pullout heading",
#               "pulloutheading",
#               "header"
#             ]
#           },
#           {
#             "level": 2,
#             "names": [
#               "subtitle"
#             ]
#           }
#         ]
#       }
#     }
#   },
#   "enrichments": [
#     {
#       "destination_field": "enriched_text",
#       "enrichment": "natural_language_understanding",
#       "options": {
#         "features": {
#           "categories": {},
#           "concepts": {
#             "limit": 8
#           },
#           "entities": {
#             "emotion": false,
#             "limit": 50,
#             "sentiment": true
#           },
#           "sentiment": {
#             "document": true
#           }
#         }
#       },
#       "source_field": "text"
#     }
#   ],
#   "normalizations": []
# }

# %% [markdown]
# There are 3 main configuration blocks that affect how input documents are processed:
#
# 1. **conversions**: How to convert documents in various formats (Word, PDF, HTML) and extract elements that indicate some structure (e.g. headings).
# 2. **enrichments**: What NLP output results are we interested in (keywords, entities, sentiment, etc.).
# 3. **normalizations**: Post-processing steps to be applied to the output. This can be left empty in most cases, unless you need the output to be normalized into a very specific format.
#
# _**Note**: The default configuration for an environment cannot be modified. If you need to change any of the options, you will need to create a new one, and then edit it. The easiest way to do this is using the service dashboard, which is described later._

# %% [markdown]
# ### Testing Language Enrichment
#
# It is a good idea to test your configuration on a small sample text before you apply it to a larger document collection.
#
# _**Note**: We have supplied a sample document (`data/sample.html`) containing the opening crawl text for Star Wars: Episode IV, but you are free to use a text of your choosing._
#
# **Q**: (optional) If you use your own sample text, provide a brief title and description below.
#
# **A**:

# %%
# Test configuration on some sample text
##Testing expires

data_dir = "data"
filename = os.path.join(data_dir, "sample.html")
with open(filename, "r") as f:
    res = discovery.add_document(environment_id=env_id, configuration_id=cfg_id, file=f, collection_id=col_id).get_result()
print(json.dumps(res, indent=2))
# Out:
# {
#   "document_id": "9582926a-93bd-4918-ac75-7bc7edd9b8d9",
#   "status": "processing"
# }

# %% [markdown]
# ### Analyze test output

# %% [markdown]
# The results returned by the service contain a _snapshot_ of the information extracted at each step of processing - document conversions, enrichments and normalizations. We are interested in the output of applying enrichments ("enrichments_output") or after normalizing them ("normalizations_output"). These should be identical if no post-processing/normalizations were specified in the configuration.

# %%
# Take a closer look at the results from the "enrichments_output" or "normalizations_output" step
output = next((s["snapshot"] for s in res["snapshots"] if s["step"] == "enrichments_output"), None)
print(json.dumps(output, indent=2))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-15-eb4d558d949f> in <module>()
#       1 # Take a closer look at the results from the "enrichments_output" or "normalizations_output" step
# ----> 2 output = next((s["snapshot"] for s in res["snapshots"] if s["step"] == "enrichments_output"), None)
#       3 print(json.dumps(output, indent=2))
#
# KeyError: 'snapshots'

# %% [markdown]
# Answer the following questions based on the output above. Note that it contains the input HTML, extracted text and metadata as well as the actual enrichment results.
#
# #### Sentiment
#
# **Q**: What is the overall sentiment detected in this text? Mention the `type` (positive/negative) and `score`.<br />
# (_Hint: Look for the `"sentiment"` key in the output._)
#
# **A**:
#
#
# #### Concepts
#
# **Q**: List 3 concepts that have been identified with a relevance > 0.5. Note that not all concepts here may be present directly in the text, some may have been inferred by Watson.<br />
# (_Hint: Look for `"concepts"`._)
#
# **A**:

# %% [markdown]
# Get a good sense of all the different pieces of information available in the results. Start thinking about which ones will be useful for looking up answers to questions, and how you might use them.

# %% [markdown]
# ## 2. Ingest documents
#
# ### Create a collection
#
# A _collection_ is used to organize documents of the same kind. For instance, you may want to create a collection of book reviews, or a collection of Wikipedia articles, but it may not make much sense to mix the two groups. This allows Watson to make meaningful inferences over the set of documents, find commonalities and identify important concepts.
#
# Let's create a collection called `Story Chunks` in the Discovery service environment.

# %%
# Prepare a collection of documents to use
col, col_id = helper.fetch_object(discovery, "collection", "Story Chunks", environment_id=env_id,
    create=True, create_args=dict(
        environment_id=env_id, configuration_id=cfg_id,
        description="Stories and plots split up into chunks suitable for answering")
    )
# Out:
# {'environment_id': '298e5cb9-1f37-4f63-bbb6-14217fdcc403', 'configuration_id': '3ffef54c-e190-4386-b5dc-3428e50fa1ad', 'description': 'Stories and plots split up into chunks suitable for answering', 'name': 'Story Chunks'}
# Created collection: Story Chunks (3a208dae-abf8-40bc-b71b-e83aa60fa768)

# %% [markdown]
# Once you have created a collection, you should be able to view it using the Discovery Service tool. Select the Discovery instance from your BlueMix dashboard.  To open, click the **`Launch tool`** button.
#
# <img src="images/discovery-launch.png" alt="Discovery service - Manage tab" width="800" />

# %% [markdown]
# Here you should see the `Story Chunks` collection you just created.
#
# <img src="images/discovery-tooling.png" alt="Discovery service - Tool showing collections" width="800" />
#
# You can open the collection to view more details about it. If you need to modify configuration options, click the **Switch** link and create a new configuration (the default one cannot be changed).

# %% [markdown]
# ### Add documents
#
# Okay, now that we have everything set up, let's add a set of "documents" we want Watson to look up answers from, using the Python SDK. Note that Watson treats each "document" as a unit of text that is returned as the result of a query. But we want to retrieve a paragraph of text for each question. So, let's split each file up into individual paragraphs. We will use the [BeautifulSoup](https://www.crummy.com/software/BeautifulSoup/bs4/doc/) library for this purpose.
#
# _**Note**: You could also add and manage documents in the collection using the Discovery tool, but you would have to split paragraphs up into separate files._
#
# _**Note**: We have provided a set of files (`data/Star-Wars/*.html`) with summary plots for Star Wars movies, but you are free to use a collection of your choice. Open one of the files in a text editor to see how the paragraphs are delimited using `<p>...</p>` tags - this is how the code block below split paragraphs into separate "documents"._

# %%
# Add documents to collection
doc_ids = []  # to store the generated id for each document added
for filename in glob.glob(os.path.join(data_dir, "Star-Wars", "*.html")):
    print("Adding file:", filename)
    with open(filename, "r") as f:
        # Split each individual <p> into its own "document"
        doc = f.read()
        soup = BeautifulSoup(doc, 'html.parser')
        for i, p in enumerate(soup.find_all('p')):
            doc_info = discovery.add_document(
                environment_id=env_id, 
                collection_id=col_id,
                file=json.dumps({"text": p.get_text(strip=True)}),
                filename='n',
                file_content_type="application/json",
                metadata=json.dumps({"title": soup.title.get_text(strip=True)})
            ).get_result() # add get_result() here

            doc_ids.append(doc_info["document_id"])
print("Total", len(doc_ids), "documents added.")
# Out:
# Adding file: data/Star-Wars/Episode-II_Attack-of-the-Clones.html
# Adding file: data/Star-Wars/Episode-VII_The-Force-Awakens.html
# Adding file: data/Star-Wars/Episode-III_Revenge-of-the-Sith.html
# Adding file: data/Star-Wars/Episode-V_The-Empire-Strikes-Back.html
# Adding file: data/Star-Wars/Episode-IV_A-New-Hope.html
# Adding file: data/Star-Wars/Rogue-One.html
# Adding file: data/Star-Wars/Episode-I_The-Phantom-Menace.html
# Adding file: data/Star-Wars/Episode-VI_Return-of-the-Jedi.html
# Total 42 documents added.

# %% [markdown]
# If you look at the collection details, you may notice that the `"document_counts"` field now shows some documents as `available` or `processing`. Once processing is complete, you should see all the documents under the `available` count.

# %%
# View collection details to verify all documents have been processed
col, col_id = helper.fetch_object(discovery, "collection", "Story Chunks", environment_id=env_id)
# Out:
# Found collection: Story Chunks (3a208dae-abf8-40bc-b71b-e83aa60fa768)

# %% [markdown]
# So, what did the Discovery service learn? If you list the fields extracted from the set of documents in the collection as part of the enrichment process, you'll see familiar fields like `concepts`, `entities` and `keywords` that were returned in the test analysis.

# %%
# List all fields extracted
discovery.list_collection_fields(environment_id=env_id, collection_id=col_id).get_result()
# Out:
# {'fields': [{'field': 'enriched_text.entities.sentiment.score',
#    'type': 'double'},
#   {'field': 'enriched_text.sentiment.document.label', 'type': 'string'},
#   {'field': 'enriched_text.concepts.dbpedia_resource', 'type': 'string'},
#   {'field': 'extracted_metadata.file_type', 'type': 'string'},
#   {'field': 'enriched_text.concepts.text', 'type': 'string'},
#   {'field': 'enriched_text.concepts.relevance', 'type': 'double'},
#   {'field': 'enriched_text.categories.score', 'type': 'double'},
#   {'field': 'enriched_text.entities.sentiment.label', 'type': 'string'},
#   {'field': 'enriched_text.entities.relevance', 'type': 'double'},
#   {'field': 'text', 'type': 'string'},
#   {'field': 'enriched_text.entities.count', 'type': 'double'},
#   {'field': 'enriched_text.entities.sentiment', 'type': 'nested'},
#   {'field': 'enriched_text.sentiment.document', 'type': 'nested'},
#   {'field': 'enriched_text.entities.text', 'type': 'string'},
#   {'field': 'enriched_text.entities', 'type': 'nested'},
#   {'field': 'enriched_text.entities.disambiguation.name', 'type': 'string'},
#   {'field': 'enriched_text.categories.label', 'type': 'string'},
#   {'field': 'id', 'type': 'string'},
#   {'field': 'enriched_text.concepts', 'type': 'nested'},
#   {'field': 'enriched_text.entities.disambiguation', 'type': 'nested'},
#   {'field': 'enriched_text.entities.type', 'type': 'string'},
#   {'field': 'extracted_metadata.sha1', 'type': 'string'},
#   {'field': 'enriched_text', 'type': 'nested'},
#   {'field': 'metadata', 'type': 'nested'},
#   {'field': 'enriched_text.categories', 'type': 'nested'},
#   {'field': 'metadata.title', 'type': 'string'},
#   {'field': 'extracted_metadata', 'type': 'nested'},
#   {'field': 'enriched_text.entities.disambiguation.subtype', 'type': 'string'},
#   {'field': 'enriched_text.sentiment', 'type': 'nested'},
#   {'field': 'enriched_text.entities.disambiguation.dbpedia_resource',
#    'type': 'string'},
#   {'field': 'enriched_text.sentiment.document.score', 'type': 'double'},
#   {'field': 'extracted_metadata.filename', 'type': 'string'}]}

# %% [markdown]
# ### Test query
#
# Let's perform a simple query to see if the service can fetch the proper document for us:
# > _Look for all paragraphs that have a relation (sentence) with "Jar Jar" as the subject, and return the title and text._

# %%
# A simple query
results = discovery.query(environment_id=env_id, collection_id=col_id,
    query_options={
        "query": "enriched_text.sentiment.document.label:\"negative\"",
        "return": "metadata.title"
    }).get_result()
print(json.dumps(results, indent=2))
# Out:
# {
#   "matching_results": 43,
#   "session_token": "1_w6zW08W9nY9jHxr1_cqS6f8WLa",
#   "results": [
#     {
#       "id": "95284412-75da-430b-aac7-1f4152f92694",
#       "result_metadata": {
#         "score": 1
#       },
#       "extracted_metadata": {
#         "sha1": "7dfa3fe8928447d3324c09832a2115bae9efe351",
#         "filename": "n",
#         "file_type": "json"
#       },
#       "text": "The Falcon is captured by a larger ship piloted by Han Solo and Chewbacca, looking to reclaim their former vessel. Two rival gangs, seeking to settle debts with Han, board and attack, but Han and his allies flee in the Falcon. The gangs inform the First Order. At the First Order's Starkiller Base \u2013 a planet converted into a superweapon that harnesses energy from stars \u2013 Supreme Leader Snoke orders General Hux to use the weapon for the first time. Snoke questions Ren's ability to deal with emotions relating to his father, Han Solo; Ren says Solo means nothing to him.",
#       "metadata": {
#         "title": "Star Wars: Episode VII - The Force Awakens"
#       },
#       "enriched_text": {
#         "sentiment": {
#           "document": {
#             "score": 0,
#             "label": "neutral"
#           }
#         },
#         "entities": [
#           {
#             "count": 6,
#             "sentiment": {
#               "score": -0.305738,
#               "label": "negative"
#             },
#             "text": "Han Solo",
#             "relevance": 0.806577,
#             "type": "Person"
#           },
#           {
#             "count": 1,
#             "sentiment": {
#               "score": 0,
#               "label": "neutral"
#             },
#             "text": "General Hux",
#             "relevance": 0.241239,
#             "type": "Company"
#           },
#           {
#             "count": 2,
#             "sentiment": {
#               "score": 0,
#               "label": "neutral"
#             },
#             "text": "Ren",
#             "relevance": 0.237616,
#             "type": "Person"
#           }
#         ],
#         "concepts": [
#           {
#             "text": "Star Wars Episode IV: A New Hope",
#             "relevance": 0.989689,
#             "dbpedia_resource": "http://dbpedia.org/resource/Star_Wars_Episode_IV:_A_New_Hope"
#           },
#           {
#             "text": "Obi-Wan Kenobi",
#             "relevance": 0.968787,
#             "dbpedia_resource": "http://dbpedia.org/resource/Obi-Wan_Kenobi"
#           },
#           {
#             "text": "Wookiee",
#             "relevance": 0.892406,
#             "dbpedia_resource": "http://dbpedia.org/resource/Wookiee"
#           },
#           {
#             "text": "Chewbacca",
#             "relevance": 0.880598,
#             "dbpedia_resource": "http://dbpedia.org/resource/Chewbacca"
#           },
#           {
#             "text": "Darth Vader",
#             "relevance": 0.870146,
#             "dbpedia_resource": "http://dbpedia.org/resource/Darth_Vader"
#           },
#           {
#             "text": "Han Solo",
#             "relevance": 0.849411,
#             "dbpedia_resource": "http://dbpedia.org/resource/Han_Solo"
#           },
#           {
#             "text": "R2-D2",
#             "relevance": 0.848201,
#             "dbpedia_resource": "http://dbpedia.org/resource/R2-D2"
#           },
#           {
#             "text": "Rebel Alliance",
#             "relevance": 0.816558,
#             "dbpedia_resource": "http://dbpedia.org/resource/Rebel_Alliance"
#           }
#         ],
#         "categories": [
#           {
#             "score": 0.78683,
#             "label": "/travel/transports"
#           },
#           {
#             "score": 0.762619,
#             "label": "/travel/transports/sea travel"
#           },
#           {
#             "score": 0.661241,
#             "label": "/society/unrest and war"
#           }
#         ]
#       }
#     },
#     {
#       "id": "41915972-ce8a-43f9-956f-76f86d974b2e",
#       "result_metadata": {
#         "score": 1
#       },
#       "extracted_metadata": {
#         "sha1": "f147b684f13755e9cfd6005a7a70596f09b61faa",
#         "filename": "n",
#         "file_type": "json"
#       },
#       "text": "Unable to convince Padm\u00e9 about Anakin's turn to the dark side, Obi-Wan stows aboard her ship. Padm\u00e9 travels to Mustafar and begs Vader to leave the dark side. He refuses, and upon witnessing Obi-Wan, chokes Padm\u00e9 into unconsciousness in a fit of rage. Obi-Wan duels and defeats Vader, leaving him for dead at the bank of a lava river. On Coruscant, Yoda battles Palpatine until their duel reaches a stalemate, and Yoda flees with Bail Organa. Palpatine, sensing that his apprentice is in danger, travels to Mustafar.",
#       "metadata": {
#         "title": "Star Wars: Episode III - Revenge of the Sith"
#       },
#       "enriched_text": {
#         "sentiment": {
#           "document": {
#             "score": -0.893783,
#             "label": "negative"
#           }
#         },
#         "entities": [
#           {
#             "count": 2,
#             "sentiment": {
#               "score": 0.328157,
#               "label": "positive"
#             },
#             "text": "Obi-Wan",
#             "relevance": 0.912536,
#             "type": "Person"
#           },
#           {
#             "count": 4,
#             "sentiment": {
#               "score": -0.681254,
#               "label": "negative"
#             },
#             "text": "Vader",
#             "relevance": 0.879243,
#             "type": "Person"
#           },
#           {
#             "count": 2,
#             "sentiment": {
#               "score": -0.691201,
#               "label": "negative"
#             },
#             "text": "Palpatine",
#             "relevance": 0.591046,
#             "type": "Person"
#           },
#           {
#             "count": 3,
#             "sentiment": {
#               "score": -0.669924,
#               "label": "negative"
#             },
#             "text": "Padm\u00e9",
#             "relevance": 0.557098,
#             "type": "Person"
#           },
#           {
#             "count": 2,
#             "sentiment": {
#               "score": -0.258498,
#               "label": "negative"
#             },
#             "text": "Mustafar",
#             "relevance": 0.404383,
#             "type": "Location",
#             "disambiguation": {
#               "subtype": [
#                 "City"
#               ]
#             }
#           }
#         ],
#         "concepts": [
#           {
#             "text": "Darth Vader",
#             "relevance": 0.975399,
#             "dbpedia_resource": "http://dbpedia.org/resource/Darth_Vader"
#           },
#           {
#             "text": "Anakin Skywalker",
#             "relevance": 0.924439,
#             "dbpedia_resource": "http://dbpedia.org/resource/Anakin_Skywalker"
#           },
#           {
#             "text": "Jedi",
#             "relevance": 0.910591,
#             "dbpedia_resource": "http://dbpedia.org/resource/Jedi"
#           },
#           {
#             "text": "Obi-Wan Kenobi",
#             "relevance": 0.896753,
#             "dbpedia_resource": "http://dbpedia.org/resource/Obi-Wan_Kenobi"
#           },
#           {
#             "text": "Luke Skywalker",
#             "relevance": 0.890176,
#             "dbpedia_resource": "http://dbpedia.org/resource/Luke_Skywalker"
#           },
#           {
#             "text": "Star Wars Episode III: Revenge of the Sith",
#             "relevance": 0.886259,
#             "dbpedia_resource": "http://dbpedia.org/resource/Star_Wars_Episode_III:_Revenge_of_the_Sith"
#           },
#           {
#             "text": "Star Wars Episode II: Attack of the Clones",
#             "relevance": 0.882566,
#             "dbpedia_resource": "http://dbpedia.org/resource/Star_Wars_Episode_II:_Attack_of_the_Clones"
#           },
#           {
#             "text": "Palpatine",
#             "relevance": 0.879995,
#             "dbpedia_resource": "http://dbpedia.org/resource/Palpatine"
#           }
#         ],
#         "categories": [
#           {
#             "score": 0.577364,
#             "label": "/law, govt and politics/politics"
#           },
#           {
#             "score": 0.57126,
#             "label": "/art and entertainment/movies"
#           },
#           {
#             "score": 0.568748,
#             "label": "/law, govt and politics/government/heads of state"
#           }
#         ]
#       }
#     },
#     {
#       "id": "8409637e-d5ad-4eb5-bfec-37c0dbeb925a",
#       "result_metadata": {
#         "score": 1
#       },
#       "extracted_metadata": {
#         "sha1": "c4014bb3fe6f1fb5ff5fe4a1eb34df348f0c0e18",
#         "filename": "n",
#         "file_type": "json"
#       },
#       "text": "Three years after the destruction of the Death Star, the Rebel Alliance has been driven from their former base on Yavin IV by the Galactic Empire. The Rebels, led by Princess Leia, have set up their new base on the ice planet Hoth. The Imperial fleet, led by Darth Vader, continues to hunt for the Rebels\u2019 new base by dispatching probe droids across the galaxy.",
#       "metadata": {
#         "title": "Star Wars: Episode V - The Empire Strikes Back"
#       },
#       "enriched_text": {
#         "sentiment": {
#           "document": {
#             "score": -0.75041,
#             "label": "negative"
#           }
#         },
#         "entities": [
#           {
#             "count": 3,
#             "sentiment": {
#               "score": 0.238317,
#               "label": "positive"
#             },
#             "text": "Rebel Alliance",
#             "relevance": 0.807131,
#             "type": "Organization",
#             "disambiguation": {
#               "subtype": [],
#               "name": "Rebel Alliance",
#               "dbpedia_resource": "http://dbpedia.org/resource/Rebel_Alliance"
#             }
#           },
#           {
#             "count": 1,
#             "sentiment": {
#               "score": -0.292477,
#               "label": "negative"
#             },
#             "text": "Darth Vader",
#             "relevance": 0.59847,
#             "type": "Person"
#           },
#           {
#             "count": 1,
#             "sentiment": {
#               "score": 0.425247,
#               "label": "positive"
#             },
#             "text": "Princess Leia",
#             "relevance": 0.580596,
#             "type": "Person"
#           },
#           {
#             "count": 1,
#             "sentiment": {
#               "score": 0,
#               "label": "neutral"
#             },
#             "text": "Galactic Empire",
#             "relevance": 0.570897,
#             "type": "Facility"
#           },
#           {
#             "count": 1,
#             "sentiment": {
#               "score": 0,
#               "label": "neutral"
#             },
#             "text": "Three years",
#             "relevance": 0.570897,
#             "type": "Quantity"
#           }
#         ],
#         "concepts": [
#           {
#             "text": "Star Wars Episode IV: A New Hope",
#             "relevance": 0.947403,
#             "dbpedia_resource": "http://dbpedia.org/resource/Star_Wars_Episode_IV:_A_New_Hope"
#           },
#           {
#             "text": "Darth Vader",
#             "relevance": 0.89423,
#             "dbpedia_resource": "http://dbpedia.org/resource/Darth_Vader"
#           },
#           {
#             "text": "Rebel Alliance",
#             "relevance": 0.894131,
#             "dbpedia_resource": "http://dbpedia.org/resource/Rebel_Alliance"
#           },
#           {
#             "text": "Star Wars Episode V: The Empire Strikes Back",
#             "relevance": 0.811135,
#             "dbpedia_resource": "http://dbpedia.org/resource/Star_Wars_Episode_V:_The_Empire_Strikes_Back"
#           },
#           {
#             "text": "Star Wars Episode VI: Return of the Jedi",
#             "relevance": 0.769414,
#             "dbpedia_resource": "http://dbpedia.org/resource/Star_Wars_Episode_VI:_Return_of_the_Jedi"
#           },
#           {
#             "text": "Luke Skywalker",
#             "relevance": 0.745122,
#             "dbpedia_resource": "http://dbpedia.org/resource/Luke_Skywalker"
#           },
#           {
#             "text": "Star Wars",
#             "relevance": 0.714044,
#             "dbpedia_resource": "http://dbpedia.org/resource/Star_Wars"
#           },
#           {
#             "text": "Padm\u00e9 Amidala",
#             "relevance": 0.661661,
#             "dbpedia_resource": "http://dbpedia.org/resource/Padm\u00e9_Amidala"
#           }
#         ],
#         "categories": [
#           {
#             "score": 0.604847,
#             "label": "/law, govt and politics/politics"
#           },
#           {
#             "score": 0.579427,
#             "label": "/travel/transports"
#           },
#           {
#             "score": 0.572844,
#             "label": "/art and entertainment/movies"
#           }
#         ]
#       }
#     },
#     {
#       "id": "94e1a242-936a-46c1-bcfb-79a43a864442",
#       "result_metadata": {
#         "score": 1
#       },
#       "extracted_metadata": {
#         "sha1": "0a47755f3ca236ea62a32f9d3f08986b1b9296e0",
#         "filename": "n",
#         "file_type": "json"
#       },
#       "text": "Vader goes back on his agreement with Lando to let Leia and Chewbacca stay in Cloud City and instead, takes them into custody. He intends to hold Luke in suspended animation in a block of carbonite for delivery to the Emperor. To test this process, he selects Han to be frozen against the protests of Fett, who fears he will lose his bounty. Vader hands the frozen Han over to Fett, who intends to leave for Tatooine to deliver Han to Jabba the Hutt and claim the bounty on Solo. Lando, who was forced into cooperating with the Empire, initiates an escape and frees Leia and the others. They then try to save Han but are too late and unable to stop Fett as he departs on his ship. They fight their way back to the Falcon and flee Cloud City.",
#       "metadata": {
#         "title": "Star Wars: Episode V - The Empire Strikes Back"
#       },
#       "enriched_text": {
#         "sentiment": {
#           "document": {
#             "score": -0.847888,
#             "label": "negative"
#           }
#         },
#         "entities": [
#           {
#             "count": 5,
#             "sentiment": {
#               "score": -0.479122,
#               "label": "negative"
#             },
#             "text": "Fett",
#             "relevance": 0.955496,
#             "type": "Person"
#           },
#           {
#             "count": 3,
#             "sentiment": {
#               "score": -0.564691,
#               "label": "negative"
#             },
#             "text": "Han",
#             "relevance": 0.948567,
#             "type": "Person"
#           },
#           {
#             "count": 2,
#             "sentiment": {
#               "score": -0.562213,
#               "label": "negative"
#             },
#             "text": "Cloud City",
#             "relevance": 0.563967,
#             "type": "Location",
#             "disambiguation": {
#               "subtype": [
#                 "City"
#               ]
#             }
#           },
#           {
#             "count": 2,
#             "sentiment": {
#               "score": -0.794134,
#               "label": "negative"
#             },
#             "text": "Lando",
#             "relevance": 0.563719,
#             "type": "Person"
#           },
#           {
#             "count": 2,
#             "sentiment": {
#               "score": -0.794134,
#               "label": "negative"
#             },
#             "text": "Leia",
#             "relevance": 0.525719,
#             "type": "Person"
#           },
#           {
#             "count": 1,
#             "sentiment": {
#               "score": -0.709305,
#               "label": "negative"
#             },
#             "text": "Luke",
#             "relevance": 0.28476,
#             "type": "Person"
#           },
#           {
#             "count": 1,
#             "sentiment": {
#               "score": -0.564691,
#               "label": "negative"
#             },
#             "text": "Tatooine",
#             "relevance": 0.279449,
#             "type": "Location",
#             "disambiguation": {
#               "subtype": [
#                 "City"
#               ]
#             }
#           },
#           {
#             "count": 1,
#             "sentiment": {
#               "score": -0.709305,
#               "label": "negative"
#             },
#             "text": "carbonite",
#             "relevance": 0.259551,
#             "type": "Company"
#           }
#         ],
#         "concepts": [
#           {
#             "text": "Star Wars Episode VI: Return of the Jedi",
#             "relevance": 0.96261,
#             "dbpedia_resource": "http://dbpedia.org/resource/Star_Wars_Episode_VI:_Return_of_the_Jedi"
#           },
#           {
#             "text": "Star Wars Episode V: The Empire Strikes Back",
#             "relevance": 0.834401,
#             "dbpedia_resource": "http://dbpedia.org/resource/Star_Wars_Episode_V:_The_Empire_Strikes_Back"
#           },
#           {
#             "text": "Darth Vader",
#             "relevance": 0.799163,
#             "dbpedia_resource": "http://dbpedia.org/resource/Darth_Vader"
#           },
#           {
#             "text": "Star Wars Episode IV: A New Hope",
#             "relevance": 0.795979,
#             "dbpedia_resource": "http://dbpedia.org/resource/Star_Wars_Episode_IV:_A_New_Hope"
#           },
#           {
#             "text": "Jabba the Hutt",
#             "relevance": 0.775692,
#             "dbpedia_resource": "http://dbpedia.org/resource/Jabba_the_Hutt"
#           },
#           {
#             "text": "Star Wars",
#             "relevance": 0.774272,
#             "dbpedia_resource": "http://dbpedia.org/resource/Star_Wars"
#           },
#           {
#             "text": "Han Solo",
#             "relevance": 0.761185,
#             "dbpedia_resource": "http://dbpedia.org/resource/Han_Solo"
#           },
#           {
#             "text": "Luke Skywalker",
#             "relevance": 0.731425,
#             "dbpedia_resource": "http://dbpedia.org/resource/Luke_Skywalker"
#           }
#         ],
#         "categories": [
#           {
#             "score": 0.566104,
#             "label": "/art and entertainment/movies"
#           },
#           {
#             "score": 0.557839,
#             "label": "/art and entertainment/movies and tv/movies"
#           },
#           {
#             "score": 0.548275,
#             "label": "/travel/transports/sea travel"
#           }
#         ]
#       }
#     },
#     {
#       "id": "1d0117f3-de8e-4b81-a1d1-ed2319a6fe4f",
#       "result_metadata": {
#         "score": 1
#       },
#       "extracted_metadata": {
#         "sha1": "483a5d301dbe9b91822d94da26190e07fe216e14",
#         "filename": "n",
#         "file_type": "json"
#       },
#       "text": "After arriving at Cloud City, and engaging in a brief confrontation with Boba Fett, Luke ultimately falls into Vader's trap. The two engage in a lightsaber duel that leads them over the city's central air shaft where, as his mentors warned, Luke proves to be no match for Vader who severs Luke's right hand, causing him to lose his weapon. After Luke refuses to join Vader against the Emperor, Vader reveals that he is Luke's father, Anakin Skywalker. Horrified by the truth, Luke throws himself off the bridge and is pulled into an air shaft. He is ejected beneath the floating city but is able to grab onto an antenna. He makes a desperate telepathic plea to Leia, who senses it and persuades Lando to return for him in the Falcon. After Luke is brought on board, they are chased by TIE fighters but R2-D2 reactivates the Falcon's hyperdrive, allowing them to escape.",
#       "metadata": {
#         "title": "Star Wars: Episode V - The Empire Strikes Back"
#       },
#       "enriched_text": {
#         "sentiment": {
#           "document": {
#             "score": -0.792059,
#             "label": "negative"
#           }
#         },
#         "entities": [
#           {
#             "count": 12,
#             "sentiment": {
#               "score": -0.312581,
#               "label": "negative"
#             },
#             "text": "Luke",
#             "relevance": 0.941474,
#             "type": "Person"
#           },
#           {
#             "count": 6,
#             "sentiment": {
#               "score": -0.58801,
#               "label": "negative"
#             },
#             "text": "Vader",
#             "relevance": 0.483592,
#             "type": "Person"
#           },
#           {
#             "count": 2,
#             "sentiment": {
#               "score": -0.578887,
#               "label": "negative"
#             },
#             "text": "Cloud City",
#             "relevance": 0.271107,
#             "type": "Company"
#           },
#           {
#             "count": 1,
#             "sentiment": {
#               "score": 0.485384,
#               "label": "positive"
#             },
#             "text": "Boba Fett",
#             "relevance": 0.194638,
#             "type": "Person"
#           },
#           {
#             "count": 1,
#             "sentiment": {
#               "score": -0.760332,
#               "label": "negative"
#             },
#             "text": "Anakin Skywalker",
#             "relevance": 0.156578,
#             "type": "Person"
#           },
#           {
#             "count": 2,
#             "sentiment": {
#               "score": 0,
#               "label": "neutral"
#             },
#             "text": "Lando",
#             "relevance": 0.141476,
#             "type": "Person"
#           },
#           {
#             "count": 1,
#             "sentiment": {
#               "score": 0.581439,
#               "label": "positive"
#             },
#             "text": "Leia",
#             "relevance": 0.141115,
#             "type": "Person"
#           }
#         ],
#         "concepts": [
#           {
#             "text": "Star Wars Episode VI: Return of the Jedi",
#             "relevance": 0.956253,
#             "dbpedia_resource": "http://dbpedia.org/resource/Star_Wars_Episode_VI:_Return_of_the_Jedi"
#           },
#           {
#             "text": "Darth Vader",
#             "relevance": 0.903459,
#             "dbpedia_resource": "http://dbpedia.org/resource/Darth_Vader"
#           },
#           {
#             "text": "Obi-Wan Kenobi",
#             "relevance": 0.797313,
#             "dbpedia_resource": "http://dbpedia.org/resource/Obi-Wan_Kenobi"
#           },
#           {
#             "text": "Star Wars Episode V: The Empire Strikes Back",
#             "relevance": 0.778385,
#             "dbpedia_resource": "http://dbpedia.org/resource/Star_Wars_Episode_V:_The_Empire_Strikes_Back"
#           },
#           {
#             "text": "Star Wars",
#             "relevance": 0.724052,
#             "dbpedia_resource": "http://dbpedia.org/resource/Star_Wars"
#           },
#           {
#             "text": "C-3PO",
#             "relevance": 0.722281,
#             "dbpedia_resource": "http://dbpedia.org/resource/C-3PO"
#           },
#           {
#             "text": "Anakin Skywalker",
#             "relevance": 0.718351,
#             "dbpedia_resource": "http://dbpedia.org/resource/Anakin_Skywalker"
#           },
#           {
#             "text": "Luke Skywalker",
#             "relevance": 0.705331,
#             "dbpedia_resource": "http://dbpedia.org/resource/Luke_Skywalker"
#           }
#         ],
#         "categories": [
#           {
#             "score": 0.60363,
#             "label": "/sports/wrestling"
#           },
#           {
#             "score": 0.602183,
#             "label": "/travel/transports"
#           },
#           {
#             "score": 0.602111,
#             "label": "/art and entertainment/shows and events"
#           }
#         ]
#       }
#     },
#     {
#       "id": "9582926a-93bd-4918-ac75-7bc7edd9b8d9",
#       "result_metadata": {
#         "score": 1
#       },
#       "extracted_metadata": {
#         "sha1": "de70c9b90d0c1d60fbabdaffae17b362e3cb2188",
#         "filename": "sample.html",
#         "file_type": "html",
#         "title": "Star Wars: Episode IV - A New Hope (Opening Crawl)"
#       },
#       "html": "<?xml version='1.0' encoding='UTF-8' standalone='yes'?><html>\n<head>\n    <meta content=\"text/html; charset=UTF-8\" http-equiv=\"Content-Type\"/>\n    <title>Star Wars: Episode IV - A New Hope (Opening Crawl)</title>\n\n</head>\n<body>\n\n    <article>\n        <h1>Star Wars: Episode IV - A New Hope (Opening Crawl)</h1>\n        <p>\n            It is a period of civil war. Rebel spaceships, striking from a hidden base, have won their first victory against the evil Galactic Empire.\n        </p><p>\n            During the battle, Rebel spies managed to steal secret plans to the Empire's ultimate weapon, the DEATH STAR, an armored space station with enough power to destroy an entire planet.\n        </p><p>\n            Pursued by the Empire's sinister agents, Princess Leia races home aboard her starship, custodian of the stolen plans that can save her people and restore freedom to the galaxy...\n        </p>\n    </article>\n</body></html>",
#       "text": "Star Wars: Episode IV - A New Hope (Opening Crawl)\n\nStar Wars: Episode IV - A New Hope (Opening Crawl)\n\nIt is a period of civil war. Rebel spaceships, striking from a hidden base, have won their first victory against the evil Galactic Empire.\n\nDuring the battle, Rebel spies managed to steal secret plans to the Empire's ultimate weapon, the DEATH STAR, an armored space station with enough power to destroy an entire planet.\n\nPursued by the Empire's sinister agents, Princess Leia races home aboard her starship, custodian of the stolen plans that can save her people and restore freedom to the galaxy...",
#       "enriched_text": {
#         "sentiment": {
#           "document": {
#             "score": 0.35128,
#             "label": "positive"
#           }
#         },
#         "entities": [],
#         "concepts": [
#           {
#             "text": "Star Wars Episode IV: A New Hope",
#             "relevance": 0.98887,
#             "dbpedia_resource": "http://dbpedia.org/resource/Star_Wars_Episode_IV:_A_New_Hope"
#           },
#           {
#             "text": "Star Wars",
#             "relevance": 0.985705,
#             "dbpedia_resource": "http://dbpedia.org/resource/Star_Wars"
#           },
#           {
#             "text": "Rebel Alliance",
#             "relevance": 0.90639,
#             "dbpedia_resource": "http://dbpedia.org/resource/Rebel_Alliance"
#           },
#           {
#             "text": "Luke Skywalker",
#             "relevance": 0.805771,
#             "dbpedia_resource": "http://dbpedia.org/resource/Luke_Skywalker"
#           },
#           {
#             "text": "Star Wars Episode V: The Empire Strikes Back",
#             "relevance": 0.801062,
#             "dbpedia_resource": "http://dbpedia.org/resource/Star_Wars_Episode_V:_The_Empire_Strikes_Back"
#           },
#           {
#             "text": "Darth Vader",
#             "relevance": 0.777337,
#             "dbpedia_resource": "http://dbpedia.org/resource/Darth_Vader"
#           },
#           {
#             "text": "Star Wars Episode VI: Return of the Jedi",
#             "relevance": 0.77159,
#             "dbpedia_resource": "http://dbpedia.org/resource/Star_Wars_Episode_VI:_Return_of_the_Jedi"
#           },
#           {
#             "text": "Grand Moff Tarkin",
#             "relevance": 0.748553,
#             "dbpedia_resource": "http://dbpedia.org/resource/Grand_Moff_Tarkin"
#           }
#         ],
#         "categories": [
#           {
#             "score": 0.70337,
#             "label": "/society/unrest and war"
#           },
#           {
#             "score": 0.680538,
#             "label": "/travel/transports/sea travel"
#           },
#           {
#             "score": 0.631002,
#             "label": "/art and entertainment/movies and tv/movies"
#           }
#         ]
#       }
#     },
#     {
#       "id": "ca12cc92-79b0-4f14-8203-e7ad52e2cda1",
#       "result_metadata": {
#         "score": 1
#       },
#       "extracted_metadata": {
#         "sha1": "7e8cf0b6e7d6d9d24d6802d0ab969f4f42a38f6b",
#         "filename": "n",
#         "file_type": "json"
#       },
#       "text": "Obi-Wan's investigation leads him to the remote ocean planet Kamino, where he discovers an army of clones is being produced for the Republic, with bounty hunter Jango Fett serving as their genetic template. Obi-Wan deduces Jango to be the bounty hunter he is seeking, and follows him and his clone son, Boba, to the desert planet Geonosis via a homing beacon placed on their ship, the Slave I. Meanwhile, Anakin becomes troubled by premonitions of his mother, Shmi, in pain, and travels to Tatooine with Padm\u00e9 to save her. They meet Owen Lars, Anakin's stepbrother and the son of Shmi's new husband, Cliegg Lars. Cliegg tells Anakin that Shmi was abducted by Tusken Raiders weeks earlier and is likely dead. Determined to find her, Anakin ventures out and finds Shmi at the Tusken campsite, where she dies in Anakin's arms. Enraged, Anakin massacres the Tuskens and returns to the Lars homestead with Shmi's body. After revealing his deed to Padm\u00e9, Anakin says that he wants to prevent death.",
#       "metadata": {
#         "title": "Star Wars: Episode II - Attack of the Clones"
#       },
#       "enriched_text": {
#         "sentiment": {
#           "document": {
#             "score": -0.701065,
#             "label": "negative"
#           }
#         },
#         "entities": [
#           {
#             "count": 8,
#             "sentiment": {
#               "score": -0.585352,
#               "label": "negative"
#             },
#             "text": "Anakin",
#             "relevance": 0.938404,
#             "type": "Person"
#           },
#           {
#             "count": 7,
#             "sentiment": {
#               "score": -0.524551,
#               "label": "negative"
#             },
#             "text": "Shmi",
#             "relevance": 0.832747,
#             "type": "Person"
#           },
#           {
#             "count": 3,
#             "sentiment": {
#               "score": -0.551205,
#               "label": "negative"
#             },
#             "text": "Cliegg Lars",
#             "relevance": 0.32508,
#             "type": "Person"
#           },
#           {
#             "count": 1,
#             "sentiment": {
#               "score": 0.504938,
#               "label": "positive"
#             },
#             "text": "Jango Fett",
#             "relevance": 0.254378,
#             "type": "Person"
#           },
#           {
#             "count": 3,
#             "sentiment": {
#               "score": 0,
#               "label": "neutral"
#             },
#             "text": "Obi-Wan",
#             "relevance": 0.226119,
#             "type": "Person"
#           },
#           {
#             "count": 1,
#             "sentiment": {
#               "score": -0.396324,
#               "label": "negative"
#             },
#             "text": "Tusken Raiders",
#             "relevance": 0.20842,
#             "type": "Organization"
#           },
#           {
#             "count": 3,
#             "sentiment": {
#               "score": 0,
#               "label": "neutral"
#             },
#             "text": "Padm\u00e9",
#             "relevance": 0.192448,
#             "type": "Person"
#           },
#           {
#             "count": 1,
#             "sentiment": {
#               "score": -0.705339,
#               "label": "negative"
#             },
#             "text": "Tusken",
#             "relevance": 0.172401,
#             "type": "Location",
#             "disambiguation": {
#               "subtype": [
#                 "City"
#               ]
#             }
#           },
#           {
#             "count": 1,
#             "sentiment": {
#               "score": 0.393253,
#               "label": "positive"
#             },
#             "text": "Boba",
#             "relevance": 0.156956,
#             "type": "Person"
#           },
#           {
#             "count": 1,
#             "sentiment": {
#               "score": 0,
#               "label": "neutral"
#             },
#             "text": "Geonosis",
#             "relevance": 0.131101,
#             "type": "Location",
#             "disambiguation": {
#               "subtype": [
#                 "City"
#               ]
#             }
#           }
#         ],
#         "concepts": [
#           {
#             "text": "Star Wars Episode II: Attack of the Clones",
#             "relevance": 0.969534,
#             "dbpedia_resource": "http://dbpedia.org/resource/Star_Wars_Episode_II:_Attack_of_the_Clones"
#           },
#           {
#             "text": "Jango Fett",
#             "relevance": 0.942901,
#             "dbpedia_resource": "http://dbpedia.org/resource/Jango_Fett"
#           },
#           {
#             "text": "Boba Fett",
#             "relevance": 0.788025,
#             "dbpedia_resource": "http://dbpedia.org/resource/Boba_Fett"
#           },
#           {
#             "text": "Obi-Wan Kenobi",
#             "relevance": 0.781814,
#             "dbpedia_resource": "http://dbpedia.org/resource/Obi-Wan_Kenobi"
#           },
#           {
#             "text": "Tatooine",
#             "relevance": 0.615965,
#             "dbpedia_resource": "http://dbpedia.org/resource/Tatooine"
#           },
#           {
#             "text": "Bounty hunter",
#             "relevance": 0.609987,
#             "dbpedia_resource": "http://dbpedia.org/resource/Bounty_hunter"
#           },
#           {
#             "text": "Star Wars characters",
#             "relevance": 0.606362,
#             "dbpedia_resource": "http://dbpedia.org/resource/Star_Wars_characters"
#           },
#           {
#             "text": "Temuera Morrison",
#             "relevance": 0.595906,
#             "dbpedia_resource": "http://dbpedia.org/resource/Temuera_Morrison"
#           }
#         ],
#         "categories": [
#           {
#             "score": 0.576414,
#             "label": "/art and entertainment/movies"
#           },
#           {
#             "score": 0.57017,
#             "label": "/law, govt and politics/politics"
#           },
#           {
#             "score": 0.570038,
#             "label": "/style and fashion/body art"
#           }
#         ]
#       }
#     },
#     {
#       "id": "5b92c93c-f1bf-4271-8ae6-55ef498e2a16",
#       "result_metadata": {
#         "score": 1
#       },
#       "extracted_metadata": {
#         "sha1": "2518058f8fe76c492664a02d668d82111c1a79ed",
#         "filename": "n",
#         "file_type": "json"
#       },
#       "text": "Starkiller Base fires and destroys the Republic capital and a portion of its fleet. The First Order attacks Takodana in search of BB-8. Han, Chewbacca, and Finn are saved by Resistance X-wing fighters led by Poe, who survived the earlier crash. Leia arrives at Takodana with C-3PO and reunites with Han and Chewbacca. Meanwhile, Ren captures Rey and takes her to Starkiller Base. However, when he interrogates her about the map, she is able to resist his mind-reading attempts. Discovering she can use the Force, she escapes using a Jedi mind trick on a nearby guard.",
#       "metadata": {
#         "title": "Star Wars: Episode VII - The Force Awakens"
#       },
#       "enriched_text": {
#         "sentiment": {
#           "document": {
#             "score": 0.670488,
#             "label": "positive"
#           }
#         },
#         "entities": [
#           {
#             "count": 3,
#             "sentiment": {
#               "score": 0,
#               "label": "neutral"
#             },
#             "text": "Han",
#             "relevance": 0.829854,
#             "type": "Person"
#           },
#           {
#             "count": 6,
#             "sentiment": {
#               "score": 0,
#               "label": "neutral"
#             },
#             "text": "Rey",
#             "relevance": 0.464344,
#             "type": "Person"
#           },
#           {
#             "count": 2,
#             "sentiment": {
#               "score": -0.320402,
#               "label": "negative"
#             },
#             "text": "Takodana",
#             "relevance": 0.459415,
#             "type": "Location",
#             "disambiguation": {
#               "subtype": [
#                 "City"
#               ]
#             }
#           },
#           {
#             "count": 1,
#             "sentiment": {
#               "score": 0,
#               "label": "neutral"
#             },
#             "text": "Starkiller Base",
#             "relevance": 0.4491,
#             "type": "GeographicFeature"
#           },
#           {
#             "count": 1,
#             "sentiment": {
#               "score": 0,
#               "label": "neutral"
#             },
#             "text": "Finn",
#             "relevance": 0.332172,
#             "type": "Person"
#           },
#           {
#             "count": 1,
#             "sentiment": {
#               "score": 0,
#               "label": "neutral"
#             },
#             "text": "Poe",
#             "relevance": 0.326253,
#             "type": "Person"
#           },
#           {
#             "count": 1,
#             "sentiment": {
#               "score": 0,
#               "label": "neutral"
#             },
#             "text": "Ren",
#             "relevance": 0.319759,
#             "type": "Person"
#           }
#         ],
#         "concepts": [
#           {
#             "text": "Luke Skywalker",
#             "relevance": 0.963566,
#             "dbpedia_resource": "http://dbpedia.org/resource/Luke_Skywalker"
#           },
#           {
#             "text": "Star Wars",
#             "relevance": 0.910631,
#             "dbpedia_resource": "http://dbpedia.org/resource/Star_Wars"
#           },
#           {
#             "text": "Star Wars Episode IV: A New Hope",
#             "relevance": 0.906126,
#             "dbpedia_resource": "http://dbpedia.org/resource/Star_Wars_Episode_IV:_A_New_Hope"
#           },
#           {
#             "text": "Darth Vader",
#             "relevance": 0.900991,
#             "dbpedia_resource": "http://dbpedia.org/resource/Darth_Vader"
#           },
#           {
#             "text": "Star Wars Episode III: Revenge of the Sith",
#             "relevance": 0.77562,
#             "dbpedia_resource": "http://dbpedia.org/resource/Star_Wars_Episode_III:_Revenge_of_the_Sith"
#           },
#           {
#             "text": "Obi-Wan Kenobi",
#             "relevance": 0.765912,
#             "dbpedia_resource": "http://dbpedia.org/resource/Obi-Wan_Kenobi"
#           },
#           {
#             "text": "Rebel Alliance",
#             "relevance": 0.750413,
#             "dbpedia_resource": "http://dbpedia.org/resource/Rebel_Alliance"
#           },
#           {
#             "text": "Yoda",
#             "relevance": 0.676399,
#             "dbpedia_resource": "http://dbpedia.org/resource/Yoda"
#           }
#         ],
#         "categories": [
#           {
#             "score": 0.612977,
#             "label": "/travel/transports"
#           },
#           {
#             "score": 0.581685,
#             "label": "/society/unrest and war"
#           },
#           {
#             "score": 0.571102,
#             "label": "/travel/transports/sea travel"
#           }
#         ]
#       }
#     },
#     {
#       "id": "23d77d97-9021-4428-8cea-e075312426ca",
#       "result_metadata": {
#         "score": 1
#       },
#       "extracted_metadata": {
#         "sha1": "49ae61effe80299160a28bbd1477d1a3fed668c3",
#         "filename": "n",
#         "file_type": "json"
#       },
#       "text": "Three years after the the start of the Clone Wars between the Galactic Republic and the Confederacy of Independent Systems, war has gripped the galaxy. During a space battle over the planet Coruscant, Jedi Knights Obi-Wan Kenobi and Anakin Skywalker lead a mission to rescue the kidnapped Supreme Chancellor Palpatine from Separatist commander General Grievous. After infiltrating Grievous's flagship, the Jedi battle Count Dooku. Anakin subdues Dooku, and on Palpatine's urging, executes him. Grievous flees the battle-torn cruiser, which the Jedi crash-land on Coruscant. There, Anakin reunites with his wife, Padm\u00e9 Amidala, who reveals she is pregnant. While initially excited, Anakin begins to have prophetic visions of Padm\u00e9 dying in childbirth, and his worry steadily grows.",
#       "metadata": {
#         "title": "Star Wars: Episode III - Revenge of the Sith"
#       },
#       "enriched_text": {
#         "sentiment": {
#           "document": {
#             "score": -0.390665,
#             "label": "negative"
#           }
#         },
#         "entities": [
#           {
#             "count": 3,
#             "sentiment": {
#               "score": -0.471802,
#               "label": "negative"
#             },
#             "text": "Anakin Skywalker",
#             "relevance": 0.91224,
#             "type": "Person"
#           },
#           {
#             "count": 3,
#             "sentiment": {
#               "score": -0.429983,
#               "label": "negative"
#             },
#             "text": "Supreme Chancellor Palpatine",
#             "relevance": 0.717952,
#             "type": "Person"
#           },
#           {
#             "count": 3,
#             "sentiment": {
#               "score": 0,
#               "label": "neutral"
#             },
#             "text": "Padm\u00e9 Amidala",
#             "relevance": 0.366826,
#             "type": "Person"
#           },
#           {
#             "count": 1,
#             "sentiment": {
#               "score": -0.493018,
#               "label": "negative"
#             },
#             "text": "Confederacy of Independent Systems",
#             "relevance": 0.313719,
#             "type": "Organization"
#           },
#           {
#             "count": 1,
#             "sentiment": {
#               "score": 0,
#               "label": "neutral"
#             },
#             "text": "commander",
#             "relevance": 0.233588,
#             "type": "JobTitle"
#           },
#           {
#             "count": 1,
#             "sentiment": {
#               "score": 0,
#               "label": "neutral"
#             },
#             "text": "Three years",
#             "relevance": 0.233588,
#             "type": "Quantity"
#           }
#         ],
#         "concepts": [
#           {
#             "text": "Palpatine",
#             "relevance": 0.930923,
#             "dbpedia_resource": "http://dbpedia.org/resource/Palpatine"
#           },
#           {
#             "text": "Anakin Skywalker",
#             "relevance": 0.915691,
#             "dbpedia_resource": "http://dbpedia.org/resource/Anakin_Skywalker"
#           },
#           {
#             "text": "Obi-Wan Kenobi",
#             "relevance": 0.829859,
#             "dbpedia_resource": "http://dbpedia.org/resource/Obi-Wan_Kenobi"
#           },
#           {
#             "text": "Star Wars Episode III: Revenge of the Sith",
#             "relevance": 0.813145,
#             "dbpedia_resource": "http://dbpedia.org/resource/Star_Wars_Episode_III:_Revenge_of_the_Sith"
#           },
#           {
#             "text": "Yoda",
#             "relevance": 0.801147,
#             "dbpedia_resource": "http://dbpedia.org/resource/Yoda"
#           },
#           {
#             "text": "Clone Wars",
#             "relevance": 0.769773,
#             "dbpedia_resource": "http://dbpedia.org/resource/Clone_Wars_(Star_Wars)"
#           },
#           {
#             "text": "Mace Windu",
#             "relevance": 0.748672,
#             "dbpedia_resource": "http://dbpedia.org/resource/Mace_Windu"
#           },
#           {
#             "text": "Star Wars Episode II: Attack of the Clones",
#             "relevance": 0.747519,
#             "dbpedia_resource": "http://dbpedia.org/resource/Star_Wars_Episode_II:_Attack_of_the_Clones"
#           }
#         ],
#         "categories": [
#           {
#             "score": 0.615547,
#             "label": "/law, govt and politics/politics"
#           },
#           {
#             "score": 0.571756,
#             "label": "/law, govt and politics/government/heads of state"
#           },
#           {
#             "score": 0.563305,
#             "label": "/art and entertainment/comics and animation/comics"
#           }
#         ]
#       }
#     },
#     {
#       "id": "84b13db4-750a-47db-96ac-632f77cae6bb",
#       "result_metadata": {
#         "score": 1
#       },
#       "extracted_metadata": {
#         "sha1": "5e25cb2202a51343431f6775252a4652bae061ec",
#         "filename": "n",
#         "file_type": "json"
#       },
#       "text": "On the asteroid Polis Massa, Obi-Wan regroups with Yoda and Padm\u00e9 gives birth to twins Luke and Leia before dying. A funeral is held for Padm\u00e9 on Naboo. On Mustafar, Palpatine finds a severely burnt Vader still alive. After returning to Coruscant, Vader's mutilated body is amputated and covered in a black armored suit. Palpatine explains to Vader that he killed Padm\u00e9 in his anger. Meanwhile, Obi-Wan and Yoda decide to conceal the twins from the Sith, as they are the galaxy's only hope for freedom. Yoda exiles himself to the planet Dagobah, while Vader and the Emperor oversee the construction of a superstation, the Death Star. Bail Organa adopts Leia as his own daughter and takes her to Alderaan, while Obi-Wan delivers Luke to his step-family Owen and Beru Lars on Tatooine, where Obi-Wan intends to watch over Luke until the time is right to challenge the Empire.",
#       "metadata": {
#         "title": "Star Wars: Episode III - Revenge of the Sith"
#       },
#       "enriched_text": {
#         "sentiment": {
#           "document": {
#             "score": -0.704862,
#             "label": "negative"
#           }
#         },
#         "entities": [
#           {
#             "count": 5,
#             "sentiment": {
#               "score": -0.648741,
#               "label": "negative"
#             },
#             "text": "Vader",
#             "relevance": 0.875983,
#             "type": "Person"
#           },
#           {
#             "count": 4,
#             "sentiment": {
#               "score": -0.253689,
#               "label": "negative"
#             },
#             "text": "Yoda",
#             "relevance": 0.615411,
#             "type": "Person"
#           },
#           {
#             "count": 3,
#             "sentiment": {
#               "score": 0.674915,
#               "label": "positive"
#             },
#             "text": "Luke",
#             "relevance": 0.474405,
#             "type": "Person"
#           },
#           {
#             "count": 1,
#             "sentiment": {
#               "score": 0,
#               "label": "neutral"
#             },
#             "text": "Obi-Wan",
#             "relevance": 0.453136,
#             "type": "Person"
#           },
#           {
#             "count": 2,
#             "sentiment": {
#               "score": -0.651221,
#               "label": "negative"
#             },
#             "text": "Palpatine",
#             "relevance": 0.435453,
#             "type": "Person"
#           },
#           {
#             "count": 2,
#             "sentiment": {
#               "score": 0.153243,
#               "label": "positive"
#             },
#             "text": "Leia",
#             "relevance": 0.416575,
#             "type": "Person"
#           },
#           {
#             "count": 1,
#             "sentiment": {
#               "score": 0,
#               "label": "neutral"
#             },
#             "text": "Polis Massa",
#             "relevance": 0.349812,
#             "type": "Person"
#           },
#           {
#             "count": 2,
#             "sentiment": {
#               "score": -0.59695,
#               "label": "negative"
#             },
#             "text": "Padm\u00e9",
#             "relevance": 0.326848,
#             "type": "Person"
#           },
#           {
#             "count": 1,
#             "sentiment": {
#               "score": 0,
#               "label": "neutral"
#             },
#             "text": "Beru Lars",
#             "relevance": 0.269581,
#             "type": "Person"
#           },
#           {
#             "count": 1,
#             "sentiment": {
#               "score": -0.368428,
#               "label": "negative"
#             },
#             "text": "Alderaan",
#             "relevance": 0.25204,
#             "type": "Location",
#             "disambiguation": {
#               "subtype": [
#                 "City"
#               ]
#             }
#           },
#           {
#             "count": 1,
#             "sentiment": {
#               "score": -0.368428,
#               "label": "negative"
#             },
#             "text": "Organa",
#             "relevance": 0.24868,
#             "type": "Person",
#             "disambiguation": {
#               "subtype": [],
#               "name": "Organa",
#               "dbpedia_resource": "http://dbpedia.org/resource/Organa"
#             }
#           },
#           {
#             "count": 1,
#             "sentiment": {
#               "score": 0,
#               "label": "neutral"
#             },
#             "text": "Mustafar",
#             "relevance": 0.198025,
#             "type": "Person"
#           },
#           {
#             "count": 1,
#             "sentiment": {
#               "score": 0,
#               "label": "neutral"
#             },
#             "text": "Owen",
#             "relevance": 0.179314,
#             "type": "Person"
#           }
#         ],
#         "concepts": [
#           {
#             "text": "Star Wars Episode III: Revenge of the Sith",
#             "relevance": 0.965363,
#             "dbpedia_resource": "http://dbpedia.org/resource/Star_Wars_Episode_III:_Revenge_of_the_Sith"
#           },
#           {
#             "text": "Star Wars",
#             "relevance": 0.891434,
#             "dbpedia_resource": "http://dbpedia.org/resource/Star_Wars"
#           },
#           {
#             "text": "Luke Skywalker",
#             "relevance": 0.809195,
#             "dbpedia_resource": "http://dbpedia.org/resource/Luke_Skywalker"
#           },
#           {
#             "text": "Star Wars Episode VI: Return of the Jedi",
#             "relevance": 0.787677,
#             "dbpedia_resource": "http://dbpedia.org/resource/Star_Wars_Episode_VI:_Return_of_the_Jedi"
#           },
#           {
#             "text": "Darth Vader",
#             "relevance": 0.778165,
#             "dbpedia_resource": "http://dbpedia.org/resource/Darth_Vader"
#           },
#           {
#             "text": "Star Wars Episode II: Attack of the Clones",
#             "relevance": 0.753415,
#             "dbpedia_resource": "http://dbpedia.org/resource/Star_Wars_Episode_II:_Attack_of_the_Clones"
#           },
#           {
#             "text": "Obi-Wan Kenobi",
#             "relevance": 0.752269,
#             "dbpedia_resource": "http://dbpedia.org/resource/Obi-Wan_Kenobi"
#           },
#           {
#             "text": "Anakin Skywalker",
#             "relevance": 0.71621,
#             "dbpedia_resource": "http://dbpedia.org/resource/Anakin_Skywalker"
#           }
#         ],
#         "categories": [
#           {
#             "score": 0.587854,
#             "label": "/law, govt and politics/government/heads of state"
#           },
#           {
#             "score": 0.578131,
#             "label": "/law, govt and politics/politics"
#           },
#           {
#             "score": 0.576106,
#             "label": "/art and entertainment/movies"
#           }
#         ]
#       }
#     }
#   ]
# }

# %% [markdown]
# Change the above query and see what results you get! Try to find one that returns relevant results, and keep that (along with the output) for review.
#
# > See [Query building reference](https://www.ibm.com/watson/developercloud/doc/discovery/query-reference.html) for descriptions of all possible parameters, operators and aggregations. You can also choose to build the query using the web interface (click the "Story Chunks" collection to query it), and then reproduce the query here.
#
# Then answer the questions below:
#
# **Q**: What query did you try? Express it in plain words below.
#
# **A**: try to find document with negative sentiment
#
#
# **Q**: What answer did you get back from Watson? You only need to mention the relevant snippet of text fro mthe paragraph(s) returned.
#
# **A**: The Falcon is captured by a larger ship piloted by Han Solo and Chewbacca, looking to reclaim their former vessel.

# %% [markdown]
# ## 3. Parse natural language questions
#
# In order to understand questions posed in natural language, we'll use another AI service called [Watson Assistant](https://console.bluemix.net/catalog/services/watson-assistant-formerly-conversation) (Formerly 'Conversation'). It can be used to design conversational agents or _chatbots_ that exhibit complex behavior, but for the purpose of this project, we'll only use it to parse certain kinds of queries.

# %% [markdown]
# ### Create a Assistant service instance
#
# Just like you did for the Discovery service, create an instance of the Assistant service. Then launch the associated tool from the service dashboard.
#
# - Go to the [IBM Bluemix Catalog](https://console.bluemix.net/catalog/).
# - Select [Watson Assistant (formerly Conversation)](https://console.bluemix.net/catalog/services/watson-assistant-formerly-conversation) service under the [AI](https://console.bluemix.net/catalog/?category=ai) category.
# - Enter a Service Name for that instance, e.g. `Assistant-Bookworm` and click **`Create`** button on the bottom right hand corner of the screen.
# - You should be able to see your newly-created service in your [Bluemix Apps Dashboard](https://console.bluemix.net/dashboard/apps).
# - Open the service instance and find your `Url` and `API Key` in **Credentials** section.
# - Copy *API Key* and *URL* into `service-credentials.json` file in this notebook:
#
# <img src="images/assistant-apikey.png" alt="Discovery Service - Credentials tab" width="600" />
#
# <img src="images/assistant-cred.png" alt="Discovery Service - Credentials tab" width="600" />

# %% [markdown]
# ### Create a Workspace from Watson Assistant console
#
# A [_workspace_](https://www.ibm.com/watson/developercloud/assistant/api/v1/python.html?python#workspaces-api) allows you to keep all the items you need for a particular application in one place, just like an _environment_ in case of the Discovery service.
#
# From Watson Assistant console, please follow these steps:
#
# 1) Click `Launch Tool` to start Watson Assistant.
# <img src="images/assistant-launch-tool.png" alt="Assistant service - Bookworm workspace" width="800" />
#
# 2) Click `Skills` tab on the navigation menu and click `Create new` button.
# <img src="images/assistant-create-new-skills.png" alt="Assistant service - Bookworm workspace" width="800" />
#
# 3) Create new skills called `Bookworm` with a suitable description, such as "I know a lot of stories. Ask me a question!".
# <img src="images/assistant-add-dialog-skills.png" alt="Assistant service - Bookworm workspace" width="800" />

# %% [markdown]
# Clicking on `Bookworm` workspace should open up a blank workspace, where you can add intents, define the entities you want the agent to idenitfy and structure the overall dialog.
#
# <img src="images/blank-workspace.png" alt="Conversation service - Blank workspace" width="800" />

# %% [markdown]
# ### Add intents
#
# An [_intent_](https://www.ibm.com/watson/developercloud/assistant/api/v1/python.html?python#intents-api) is the goal or purpose of a user's input. Intent will determine the dialog flows with the users and allow Watson Assistant to provide a useful response. Please read Watson Assistant documentation on [_Planning Your Intents and Entities_](https://console.bluemix.net/docs/services/conversation/intents-entities.html#planning-your-entities).
#
# Your task is to create a set of intents (at least 3) that capture the different kinds of questions that you want the system to answer, e.g. _who_, _what_ and _where_. Along with each intent, add a list of user examples or _utterances_ that map to that intent.
#
# For instance, you could enter the following examples for the _where_ intent:
#
# - Where is the Jedi temple located?
# - Where was Luke born?
#
# _Intent user examples should represent typical sentences that end users will use to interact with the application. The more examples you can provide for each intent, the better Watson Assistant will respond to the end user._
#
# <img src="images/assistant-intents.png" alt="Assistant service - Intents listed" width="800" />
#
# > See [**Defining intents**](https://console.bluemix.net/docs/services/conversation/intents.html#defining-intents) for a helpful video and further instructions.
#
# **Q**: What intents did you add to the Assistant service instance?
#
# **A**: who, what, where
#
#
#
# **Q**: Pick one of these intents, and list at least 5 examples for the intent that you entered.
#
# **A**: what does he do on the spaceship?

# %% [markdown]
# ### Add entities
#
# Once you have your intents set, let's tell the service what [_entities_](https://www.ibm.com/watson/developercloud/assistant/api/v1/python.html?python#entities-api) we want it to identify. One way to do this is using the `Entities` tool on Watson Assistant console, and entering them one-by-one to the blank `My entities` page.
#
# <img src="images/assistant-entities-blank.png" alt="Assistant service - No entities listed" width="800" />
#
# > Go to [**Defining entities**](https://console.bluemix.net/docs/services/conversation/entities.html#defining-entities) to see how that is done.
#
# But that can be tedious! So let's refer back to the entities that the Discovery service identified, and load them in programmatically.
#
# As before, let's connect to the Assistant service first. Remember to enter your service credentials below.

# %%
# Connect to the Assistant service instance
# TODO: Enter your username and password from the Service Credentials tab in service-credentials.json

assistant_cred = helper.fetch_credentials('assistant')

assistant = watson_developer_cloud.AssistantV1(
                        version='2018-08-01',
                        url=assistant_cred['url'],
                        iam_apikey=assistant_cred['apikey'])
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:9: DeprecationWarning: watson-developer-cloud moved to ibm-watson. To get updates, use the new package.
#   if __name__ == '__main__':

# %% [markdown]
# Fetch the workspace you just created called "Bookworm".

# %%
wrk, wrk_id = helper.fetch_object(assistant, "workspace", "Bookworm")
# Out:
# Found workspace: Bookworm (b6164755-8dfc-4779-ae97-8d442fe5e2c8)

# %% [markdown]
# ### Exporting entities from Discovery service to Assistant service
#
# Next step is to collect all the entities from the `Star Wars` documents that we added to the **Discovery** service collection and group them by entities type.

# %%
# Get all the entities from the collection and group them by type
response = discovery.query(environment_id=env_id, collection_id=col_id,
    query_options={
        "return": "enriched_text.entities.type,enriched_text.entities.text"
    }).get_result()

# Group individual entities by type ("Person", "Location", etc.)
entities_by_type = {}
for document in response["results"]:
    for entity in document["enriched_text"]["entities"]:
        if entity["type"] not in entities_by_type:
            entities_by_type[entity["type"]] = set()
        entities_by_type[entity["type"]].add(entity["text"])

# Ignore case to avoid duplicates
for entity_type in entities_by_type:
    entities_by_type[entity_type] = {
        e.lower(): e for e in entities_by_type[entity_type]
    }.values()

# Restructure for loading into Assistant workspace
entities_grouped = [{
    "entity": entity_type,
    "values": [{"value": entity} for entity in entities]}
        for entity_type, entities in entities_by_type.items()]
entities_grouped
# Out:
# [{'entity': 'Person',
#   'values': [{'value': 'Princess Leia'},
#    {'value': 'Polis Massa'},
#    {'value': 'Obi-Wan'},
#    {'value': 'Ren'},
#    {'value': 'Shmi'},
#    {'value': 'Poe'},
#    {'value': 'Vader'},
#    {'value': 'Darth Vader'},
#    {'value': 'Luke'},
#    {'value': 'Boba Fett'},
#    {'value': 'Anakin Skywalker'},
#    {'value': 'Boba'},
#    {'value': 'Supreme Chancellor Palpatine'},
#    {'value': 'Lando'},
#    {'value': 'Palpatine'},
#    {'value': 'Padmé'},
#    {'value': 'Yoda'},
#    {'value': 'Beru Lars'},
#    {'value': 'Finn'},
#    {'value': 'Mustafar'},
#    {'value': 'Padmé Amidala'},
#    {'value': 'Organa'},
#    {'value': 'Jango Fett'},
#    {'value': 'Han'},
#    {'value': 'Cliegg Lars'},
#    {'value': 'Anakin'},
#    {'value': 'Leia'},
#    {'value': 'Owen'},
#    {'value': 'Han Solo'},
#    {'value': 'Rey'},
#    {'value': 'Fett'}]},
#  {'entity': 'Company',
#   'values': [{'value': 'General Hux'},
#    {'value': 'Cloud City'},
#    {'value': 'carbonite'}]},
#  {'entity': 'Location',
#   'values': [{'value': 'Takodana'},
#    {'value': 'Geonosis'},
#    {'value': 'Tusken'},
#    {'value': 'Mustafar'},
#    {'value': 'Cloud City'},
#    {'value': 'Alderaan'},
#    {'value': 'Tatooine'}]},
#  {'entity': 'Organization',
#   'values': [{'value': 'Tusken Raiders'},
#    {'value': 'Confederacy of Independent Systems'},
#    {'value': 'Rebel Alliance'}]},
#  {'entity': 'Facility', 'values': [{'value': 'Galactic Empire'}]},
#  {'entity': 'Quantity', 'values': [{'value': 'Three years'}]},
#  {'entity': 'GeographicFeature', 'values': [{'value': 'Starkiller Base'}]},
#  {'entity': 'JobTitle', 'values': [{'value': 'commander'}]}]

# %% [markdown]
# Update the workspace with these entities and verify that have been added correctly.

# %%
# Add these grouped entities to the Assistant workspace
assistant.update_workspace(workspace_id=wrk_id, entities=entities_grouped).get_result()

workspace_details = assistant.get_workspace(workspace_id=wrk_id, export=True).get_result()
print(json.dumps(workspace_details["entities"], indent=2))
# Out:
# [
#   {
#     "entity": "Location",
#     "values": [
#       {
#         "type": "synonyms",
#         "value": "Cloud City",
#         "synonyms": []
#       },
#       {
#         "type": "synonyms",
#         "value": "Alderaan",
#         "synonyms": []
#       },
#       {
#         "type": "synonyms",
#         "value": "Tatooine",
#         "synonyms": []
#       },
#       {
#         "type": "synonyms",
#         "value": "Takodana",
#         "synonyms": []
#       },
#       {
#         "type": "synonyms",
#         "value": "Geonosis",
#         "synonyms": []
#       },
#       {
#         "type": "synonyms",
#         "value": "Tusken",
#         "synonyms": []
#       },
#       {
#         "type": "synonyms",
#         "value": "Mustafar",
#         "synonyms": []
#       }
#     ]
#   },
#   {
#     "entity": "Quantity",
#     "values": [
#       {
#         "type": "synonyms",
#         "value": "Three years",
#         "synonyms": []
#       }
#     ]
#   },
#   {
#     "entity": "Facility",
#     "values": [
#       {
#         "type": "synonyms",
#         "value": "Galactic Empire",
#         "synonyms": []
#       }
#     ]
#   },
#   {
#     "entity": "Company",
#     "values": [
#       {
#         "type": "synonyms",
#         "value": "carbonite",
#         "synonyms": []
#       },
#       {
#         "type": "synonyms",
#         "value": "Cloud City",
#         "synonyms": []
#       },
#       {
#         "type": "synonyms",
#         "value": "General Hux",
#         "synonyms": []
#       }
#     ]
#   },
#   {
#     "entity": "Person",
#     "values": [
#       {
#         "type": "synonyms",
#         "value": "Princess Leia",
#         "synonyms": []
#       },
#       {
#         "type": "synonyms",
#         "value": "Lando",
#         "synonyms": []
#       },
#       {
#         "type": "synonyms",
#         "value": "Palpatine",
#         "synonyms": []
#       },
#       {
#         "type": "synonyms",
#         "value": "Padm\u00e9",
#         "synonyms": []
#       },
#       {
#         "type": "synonyms",
#         "value": "Yoda",
#         "synonyms": []
#       },
#       {
#         "type": "synonyms",
#         "value": "Beru Lars",
#         "synonyms": []
#       },
#       {
#         "type": "synonyms",
#         "value": "Finn",
#         "synonyms": []
#       },
#       {
#         "type": "synonyms",
#         "value": "Mustafar",
#         "synonyms": []
#       },
#       {
#         "type": "synonyms",
#         "value": "Padm\u00e9 Amidala",
#         "synonyms": []
#       },
#       {
#         "type": "synonyms",
#         "value": "Organa",
#         "synonyms": []
#       },
#       {
#         "type": "synonyms",
#         "value": "Jango Fett",
#         "synonyms": []
#       },
#       {
#         "type": "synonyms",
#         "value": "Han",
#         "synonyms": []
#       },
#       {
#         "type": "synonyms",
#         "value": "Cliegg Lars",
#         "synonyms": []
#       },
#       {
#         "type": "synonyms",
#         "value": "Anakin",
#         "synonyms": []
#       },
#       {
#         "type": "synonyms",
#         "value": "Leia",
#         "synonyms": []
#       },
#       {
#         "type": "synonyms",
#         "value": "Owen",
#         "synonyms": []
#       },
#       {
#         "type": "synonyms",
#         "value": "Han Solo",
#         "synonyms": []
#       },
#       {
#         "type": "synonyms",
#         "value": "Rey",
#         "synonyms": []
#       },
#       {
#         "type": "synonyms",
#         "value": "Fett",
#         "synonyms": []
#       },
#       {
#         "type": "synonyms",
#         "value": "Supreme Chancellor Palpatine",
#         "synonyms": []
#       },
#       {
#         "type": "synonyms",
#         "value": "Polis Massa",
#         "synonyms": []
#       },
#       {
#         "type": "synonyms",
#         "value": "Obi-Wan",
#         "synonyms": []
#       },
#       {
#         "type": "synonyms",
#         "value": "Ren",
#         "synonyms": []
#       },
#       {
#         "type": "synonyms",
#         "value": "Shmi",
#         "synonyms": []
#       },
#       {
#         "type": "synonyms",
#         "value": "Poe",
#         "synonyms": []
#       },
#       {
#         "type": "synonyms",
#         "value": "Vader",
#         "synonyms": []
#       },
#       {
#         "type": "synonyms",
#         "value": "Darth Vader",
#         "synonyms": []
#       },
#       {
#         "type": "synonyms",
#         "value": "Luke",
#         "synonyms": []
#       },
#       {
#         "type": "synonyms",
#         "value": "Boba Fett",
#         "synonyms": []
#       },
#       {
#         "type": "synonyms",
#         "value": "Anakin Skywalker",
#         "synonyms": []
#       },
#       {
#         "type": "synonyms",
#         "value": "Boba",
#         "synonyms": []
#       }
#     ]
#   },
#   {
#     "entity": "GeographicFeature",
#     "values": [
#       {
#         "type": "synonyms",
#         "value": "Starkiller Base",
#         "synonyms": []
#       }
#     ]
#   },
#   {
#     "entity": "Organization",
#     "values": [
#       {
#         "type": "synonyms",
#         "value": "Rebel Alliance",
#         "synonyms": []
#       },
#       {
#         "type": "synonyms",
#         "value": "Confederacy of Independent Systems",
#         "synonyms": []
#       },
#       {
#         "type": "synonyms",
#         "value": "Tusken Raiders",
#         "synonyms": []
#       }
#     ]
#   },
#   {
#     "entity": "JobTitle",
#     "values": [
#       {
#         "type": "synonyms",
#         "value": "commander",
#         "synonyms": []
#       }
#     ]
#   }
# ]

# %% [markdown]
# _**Note**: Ensure that at least 3 entity types, with at least 1 example entity each have been added._
#
# Here is what the list of entities should look like through the Assistant tool.
#
# <img src="images/assistant-entities.png" alt="Assistant service - Entities listed" width="800" />
#
# **Q**: Name 3 entity types that were added, with at least 1 example entity each (e.g. entity type: _City_, example: _Los Angeles_).
#
# **A**: Company (carbonite), Jobtitle (commander), Person (Fett)

# %% [markdown]
# ### Design dialog flow
#
# As a final step in creating the Assistant interface, let's design a typical dialog with a user. The most intuitive way to do this is to use the Dialog tab in the tool. Here, you can add _nodes_ that capture different stages in the dialog flow, and connect them in a meaningful way.
#
# Go ahead and add at least 3 dialog nodes. Specify the triggers in terms of the intents and entities that you'd like to match, and an optional intermediate response like "Let me find that out for you." The actual response will be fetched by querying the Discovery service.
#
# Here is what the dialog nodes should look like.
#
# <img src="images/assistant_dialog_nodes.png" alt="Assistant service - Dialog nodes" width="800" />
#
# **Q**: Specify 3 dialog nodes you added, along with the trigger (intent and/or entities) for each.
#
# **A**: Location (#where), Person (#who), Object (#what)

# %% [markdown]
# ### Test dialog
#
# Let's run through a test dialog to demonstrate how the system transitions to one of the nodes you defined above.

# %%
# Testing the dialog flow

# Start conversation with a blank message
results = assistant.message(workspace_id=wrk_id).get_result()
context = results["context"]

# Then ask a sample question
question= "what is Luke's job?"
results = assistant.message(workspace_id=wrk_id,
                            input={'text': question}, context=context).get_result()

print(json.dumps(results, indent=2))
# Out:
# {
#   "intents": [
#     {
#       "intent": "what",
#       "confidence": 0.26596432326800823
#     }
#   ],
#   "entities": [
#     {
#       "entity": "Person",
#       "location": [
#         8,
#         12
#       ],
#       "value": "Luke",
#       "confidence": 1
#     }
#   ],
#   "input": {
#     "text": "what is Luke's job?"
#   },
#   "output": {
#     "generic": [
#       {
#         "response_type": "suggestion",
#         "title": "Did you mean:",
#         "suggestions": [
#           {
#             "label": "Object",
#             "value": {
#               "intents": [
#                 {
#                   "intent": "what",
#                   "confidence": 0.26596432326800823
#                 }
#               ],
#               "entities": [
#                 {
#                   "entity": "Person",
#                   "location": [
#                     8,
#                     12
#                   ],
#                   "value": "Luke",
#                   "confidence": 1
#                 }
#               ],
#               "input": {
#                 "suggestion_id": "d:e55db2f8-b768-4d03-9b5f-514ed735122f",
#                 "text": "what is Luke's job?"
#               }
#             },
#             "output": {
#               "text": [],
#               "generic": [],
#               "nodes_visited_details": [
#                 {
#                   "dialog_node": "node_8_1590387407832",
#                   "title": "Object",
#                   "conditions": "#what"
#                 }
#               ]
#             },
#             "source_dialog_node": "root",
#             "dialog_node": "node_8_1590387407832",
#             "internal": {
#               "propensity": 1
#             }
#           },
#           {
#             "label": "Person",
#             "value": {
#               "intents": [
#                 {
#                   "intent": "who",
#                   "confidence": 0.24591084717426387
#                 }
#               ],
#               "entities": [
#                 {
#                   "entity": "Person",
#                   "location": [
#                     8,
#                     12
#                   ],
#                   "value": "Luke",
#                   "confidence": 1
#                 }
#               ],
#               "input": {
#                 "suggestion_id": "d:5d7b873e-b7ae-4450-81a0-dd9f3a78a72e",
#                 "text": "what is Luke's job?"
#               }
#             },
#             "output": {
#               "text": [
#                 "I will find a person for you"
#               ],
#               "generic": [
#                 {
#                   "response_type": "text",
#                   "text": "I will find a person for you"
#                 }
#               ],
#               "nodes_visited_details": [
#                 {
#                   "dialog_node": "node_2_1590387333775",
#                   "title": "Person",
#                   "conditions": "#who"
#                 }
#               ]
#             },
#             "source_dialog_node": "root",
#             "dialog_node": "node_2_1590387333775",
#             "internal": {
#               "propensity": 1
#             }
#           },
#           {
#             "label": "None of the above",
#             "value": {
#               "intents": [],
#               "entities": [
#                 {
#                   "entity": "Person",
#                   "location": [
#                     8,
#                     12
#                   ],
#                   "value": "Luke",
#                   "confidence": 1
#                 }
#               ],
#               "input": {
#                 "suggestion_id": "d:8fe7e3ff-a2a8-4add-9be1-dc1710af5f69",
#                 "text": "what is Luke's job?"
#               }
#             },
#             "output": {
#               "text": [],
#               "generic": []
#             },
#             "source_dialog_node": "root",
#             "internal": {
#               "propensity": 1
#             }
#           }
#         ]
#       }
#     ],
#     "text": [],
#     "nodes_visited": [
#       "root"
#     ],
#     "log_messages": []
#   },
#   "context": {
#     "conversation_id": "5a3dc581-13e7-412a-8174-c36efb7551ef",
#     "system": {
#       "_node_output_map": {
#         "Welcome": {
#           "0": [
#             0
#           ]
#         }
#       },
#       "dialog_request_counter": 2,
#       "dialog_stack": [
#         {
#           "dialog_node": "root"
#         }
#       ],
#       "dialog_turn_counter": 2,
#       "initialized": true
#     }
#   }
# }

# %% [markdown]
# ## 4. Query document collection to fetch answers
#
# The Discovery service includes a simple mechanism to make queries against your enriched collection of documents. But you have a lot of control over what fields are searched, how results are aggregated and values are returned.
#
# ### Process sample question
#
# Choose a sample nautal language question to ask, and run it through the Assistant service, just like you did above when testing dialog flow.

# %%
# TODO: Run a sample question through Assistant service

# Then ask a sample question
question= "what is Luke's job?"
results = assistant.message(workspace_id=wrk_id,
                            input={'text': question}, context=context).get_result()

print(json.dumps(results, indent=2))
# Out:
# {
#   "intents": [
#     {
#       "intent": "what",
#       "confidence": 0.26596432326800823
#     }
#   ],
#   "entities": [
#     {
#       "entity": "Person",
#       "location": [
#         8,
#         12
#       ],
#       "value": "Luke",
#       "confidence": 1
#     }
#   ],
#   "input": {
#     "text": "what is Luke's job?"
#   },
#   "output": {
#     "generic": [
#       {
#         "response_type": "suggestion",
#         "title": "Did you mean:",
#         "suggestions": [
#           {
#             "label": "Person",
#             "value": {
#               "intents": [
#                 {
#                   "intent": "who",
#                   "confidence": 0.24591084717426387
#                 }
#               ],
#               "entities": [
#                 {
#                   "entity": "Person",
#                   "location": [
#                     8,
#                     12
#                   ],
#                   "value": "Luke",
#                   "confidence": 1
#                 }
#               ],
#               "input": {
#                 "suggestion_id": "d:286e547e-61b9-4b80-a2a2-6b2a3271b79a",
#                 "text": "what is Luke's job?"
#               }
#             },
#             "output": {
#               "text": [
#                 "I will find a person for you"
#               ],
#               "generic": [
#                 {
#                   "response_type": "text",
#                   "text": "I will find a person for you"
#                 }
#               ],
#               "nodes_visited_details": [
#                 {
#                   "dialog_node": "node_2_1590387333775",
#                   "title": "Person",
#                   "conditions": "#who"
#                 }
#               ]
#             },
#             "source_dialog_node": "root",
#             "dialog_node": "node_2_1590387333775",
#             "internal": {
#               "propensity": 1
#             }
#           },
#           {
#             "label": "Object",
#             "value": {
#               "intents": [
#                 {
#                   "intent": "what",
#                   "confidence": 0.26596432326800823
#                 }
#               ],
#               "entities": [
#                 {
#                   "entity": "Person",
#                   "location": [
#                     8,
#                     12
#                   ],
#                   "value": "Luke",
#                   "confidence": 1
#                 }
#               ],
#               "input": {
#                 "suggestion_id": "d:ca06a405-b19e-41bf-a513-cb7cb0dc3fe8",
#                 "text": "what is Luke's job?"
#               }
#             },
#             "output": {
#               "text": [],
#               "generic": [],
#               "nodes_visited_details": [
#                 {
#                   "dialog_node": "node_8_1590387407832",
#                   "title": "Object",
#                   "conditions": "#what"
#                 }
#               ]
#             },
#             "source_dialog_node": "root",
#             "dialog_node": "node_8_1590387407832",
#             "internal": {
#               "propensity": 1
#             }
#           },
#           {
#             "label": "None of the above",
#             "value": {
#               "intents": [],
#               "entities": [
#                 {
#                   "entity": "Person",
#                   "location": [
#                     8,
#                     12
#                   ],
#                   "value": "Luke",
#                   "confidence": 1
#                 }
#               ],
#               "input": {
#                 "suggestion_id": "d:dd95f473-6e9e-4bd5-9efe-a7aa9518881c",
#                 "text": "what is Luke's job?"
#               }
#             },
#             "output": {
#               "text": [],
#               "generic": []
#             },
#             "source_dialog_node": "root",
#             "internal": {
#               "propensity": 1
#             }
#           }
#         ]
#       }
#     ],
#     "text": [],
#     "nodes_visited": [
#       "root"
#     ],
#     "log_messages": []
#   },
#   "context": {
#     "conversation_id": "afbb1f66-6537-4f81-a3bd-f77d6cc6c81d",
#     "system": {
#       "_node_output_map": {
#         "Welcome": {
#           "0": [
#             0
#           ]
#         }
#       },
#       "dialog_request_counter": 2,
#       "dialog_stack": [
#         {
#           "dialog_node": "root"
#         }
#       ],
#       "dialog_turn_counter": 2,
#       "initialized": true
#     }
#   }
# }

# %% [markdown]
# Now extract the intent and entities identified in the question, and optionally what dialog node was triggered (in case you need it later to customize your response). Some sample code is provided below, but you may need to modify it.

# %%
# TODO: Identify the intent(s) the user expressed (typically a single one)
query_intents = [intent["intent"] for intent in results["intents"]]
print("Intent(s):", query_intents)

# TODO: Extract the entities found in the question text
query_entities = [entity["value"] for entity in results["entities"]]
print("Entities:", query_entities)

# TODO: (optional) Find out what dialog node was triggered
# Out:
# Intent(s): ['what']
# Entities: ['Luke']

# %% [markdown]
# ### Query the collection
#
# Design a query based on the information extracted above, and run it against the document collection. The sample query provided below simple looks for all the entities in the raw `text` field. Modify it to suit your needs.
#
# Take a look at the [API Reference](https://www.ibm.com/watson/developercloud/discovery/api/v1/?python#query-collection) to learn more about the query options available, and for more guidance see this [documentation page](https://www.ibm.com/watson/developercloud/doc/discovery/using.html).
#
# _**Note**: You may want to design different queries based on the intent / dialog node that was triggered._

# %%
# TODO: Query the Discovery service based on the intent and entities
query_results = discovery.query(environment_id=env_id, collection_id=col_id,
    query_options={
        "query": "text:{}, enriched_text.entities.type:\"JobTitle\"".format(",".join("\"{}\"".format(e) for e in query_entities)),
        "return": "text"
    }).get_result()
print(json.dumps(query_results, indent=2))
# Out:
# {
#   "matching_results": 43,
#   "session_token": "1_w6zW08W9nY9YZAz1_cqS6f8WLa",
#   "results": [
#     {
#       "id": "95284412-75da-430b-aac7-1f4152f92694",
#       "result_metadata": {
#         "score": 1
#       },
#       "extracted_metadata": {
#         "sha1": "7dfa3fe8928447d3324c09832a2115bae9efe351",
#         "filename": "n",
#         "file_type": "json"
#       },
#       "text": "The Falcon is captured by a larger ship piloted by Han Solo and Chewbacca, looking to reclaim their former vessel. Two rival gangs, seeking to settle debts with Han, board and attack, but Han and his allies flee in the Falcon. The gangs inform the First Order. At the First Order's Starkiller Base \u2013 a planet converted into a superweapon that harnesses energy from stars \u2013 Supreme Leader Snoke orders General Hux to use the weapon for the first time. Snoke questions Ren's ability to deal with emotions relating to his father, Han Solo; Ren says Solo means nothing to him.",
#       "metadata": {
#         "title": "Star Wars: Episode VII - The Force Awakens"
#       },
#       "enriched_text": {
#         "sentiment": {
#           "document": {
#             "score": 0,
#             "label": "neutral"
#           }
#         },
#         "entities": [
#           {
#             "count": 6,
#             "sentiment": {
#               "score": -0.305738,
#               "label": "negative"
#             },
#             "text": "Han Solo",
#             "relevance": 0.806577,
#             "type": "Person"
#           },
#           {
#             "count": 1,
#             "sentiment": {
#               "score": 0,
#               "label": "neutral"
#             },
#             "text": "General Hux",
#             "relevance": 0.241239,
#             "type": "Company"
#           },
#           {
#             "count": 2,
#             "sentiment": {
#               "score": 0,
#               "label": "neutral"
#             },
#             "text": "Ren",
#             "relevance": 0.237616,
#             "type": "Person"
#           }
#         ],
#         "concepts": [
#           {
#             "text": "Star Wars Episode IV: A New Hope",
#             "relevance": 0.989689,
#             "dbpedia_resource": "http://dbpedia.org/resource/Star_Wars_Episode_IV:_A_New_Hope"
#           },
#           {
#             "text": "Obi-Wan Kenobi",
#             "relevance": 0.968787,
#             "dbpedia_resource": "http://dbpedia.org/resource/Obi-Wan_Kenobi"
#           },
#           {
#             "text": "Wookiee",
#             "relevance": 0.892406,
#             "dbpedia_resource": "http://dbpedia.org/resource/Wookiee"
#           },
#           {
#             "text": "Chewbacca",
#             "relevance": 0.880598,
#             "dbpedia_resource": "http://dbpedia.org/resource/Chewbacca"
#           },
#           {
#             "text": "Darth Vader",
#             "relevance": 0.870146,
#             "dbpedia_resource": "http://dbpedia.org/resource/Darth_Vader"
#           },
#           {
#             "text": "Han Solo",
#             "relevance": 0.849411,
#             "dbpedia_resource": "http://dbpedia.org/resource/Han_Solo"
#           },
#           {
#             "text": "R2-D2",
#             "relevance": 0.848201,
#             "dbpedia_resource": "http://dbpedia.org/resource/R2-D2"
#           },
#           {
#             "text": "Rebel Alliance",
#             "relevance": 0.816558,
#             "dbpedia_resource": "http://dbpedia.org/resource/Rebel_Alliance"
#           }
#         ],
#         "categories": [
#           {
#             "score": 0.78683,
#             "label": "/travel/transports"
#           },
#           {
#             "score": 0.762619,
#             "label": "/travel/transports/sea travel"
#           },
#           {
#             "score": 0.661241,
#             "label": "/society/unrest and war"
#           }
#         ]
#       }
#     },
#     {
#       "id": "41915972-ce8a-43f9-956f-76f86d974b2e",
#       "result_metadata": {
#         "score": 1
#       },
#       "extracted_metadata": {
#         "sha1": "f147b684f13755e9cfd6005a7a70596f09b61faa",
#         "filename": "n",
#         "file_type": "json"
#       },
#       "text": "Unable to convince Padm\u00e9 about Anakin's turn to the dark side, Obi-Wan stows aboard her ship. Padm\u00e9 travels to Mustafar and begs Vader to leave the dark side. He refuses, and upon witnessing Obi-Wan, chokes Padm\u00e9 into unconsciousness in a fit of rage. Obi-Wan duels and defeats Vader, leaving him for dead at the bank of a lava river. On Coruscant, Yoda battles Palpatine until their duel reaches a stalemate, and Yoda flees with Bail Organa. Palpatine, sensing that his apprentice is in danger, travels to Mustafar.",
#       "metadata": {
#         "title": "Star Wars: Episode III - Revenge of the Sith"
#       },
#       "enriched_text": {
#         "sentiment": {
#           "document": {
#             "score": -0.893783,
#             "label": "negative"
#           }
#         },
#         "entities": [
#           {
#             "count": 2,
#             "sentiment": {
#               "score": 0.328157,
#               "label": "positive"
#             },
#             "text": "Obi-Wan",
#             "relevance": 0.912536,
#             "type": "Person"
#           },
#           {
#             "count": 4,
#             "sentiment": {
#               "score": -0.681254,
#               "label": "negative"
#             },
#             "text": "Vader",
#             "relevance": 0.879243,
#             "type": "Person"
#           },
#           {
#             "count": 2,
#             "sentiment": {
#               "score": -0.691201,
#               "label": "negative"
#             },
#             "text": "Palpatine",
#             "relevance": 0.591046,
#             "type": "Person"
#           },
#           {
#             "count": 3,
#             "sentiment": {
#               "score": -0.669924,
#               "label": "negative"
#             },
#             "text": "Padm\u00e9",
#             "relevance": 0.557098,
#             "type": "Person"
#           },
#           {
#             "count": 2,
#             "sentiment": {
#               "score": -0.258498,
#               "label": "negative"
#             },
#             "text": "Mustafar",
#             "relevance": 0.404383,
#             "type": "Location",
#             "disambiguation": {
#               "subtype": [
#                 "City"
#               ]
#             }
#           }
#         ],
#         "concepts": [
#           {
#             "text": "Darth Vader",
#             "relevance": 0.975399,
#             "dbpedia_resource": "http://dbpedia.org/resource/Darth_Vader"
#           },
#           {
#             "text": "Anakin Skywalker",
#             "relevance": 0.924439,
#             "dbpedia_resource": "http://dbpedia.org/resource/Anakin_Skywalker"
#           },
#           {
#             "text": "Jedi",
#             "relevance": 0.910591,
#             "dbpedia_resource": "http://dbpedia.org/resource/Jedi"
#           },
#           {
#             "text": "Obi-Wan Kenobi",
#             "relevance": 0.896753,
#             "dbpedia_resource": "http://dbpedia.org/resource/Obi-Wan_Kenobi"
#           },
#           {
#             "text": "Luke Skywalker",
#             "relevance": 0.890176,
#             "dbpedia_resource": "http://dbpedia.org/resource/Luke_Skywalker"
#           },
#           {
#             "text": "Star Wars Episode III: Revenge of the Sith",
#             "relevance": 0.886259,
#             "dbpedia_resource": "http://dbpedia.org/resource/Star_Wars_Episode_III:_Revenge_of_the_Sith"
#           },
#           {
#             "text": "Star Wars Episode II: Attack of the Clones",
#             "relevance": 0.882566,
#             "dbpedia_resource": "http://dbpedia.org/resource/Star_Wars_Episode_II:_Attack_of_the_Clones"
#           },
#           {
#             "text": "Palpatine",
#             "relevance": 0.879995,
#             "dbpedia_resource": "http://dbpedia.org/resource/Palpatine"
#           }
#         ],
#         "categories": [
#           {
#             "score": 0.577364,
#             "label": "/law, govt and politics/politics"
#           },
#           {
#             "score": 0.57126,
#             "label": "/art and entertainment/movies"
#           },
#           {
#             "score": 0.568748,
#             "label": "/law, govt and politics/government/heads of state"
#           }
#         ]
#       }
#     },
#     {
#       "id": "8409637e-d5ad-4eb5-bfec-37c0dbeb925a",
#       "result_metadata": {
#         "score": 1
#       },
#       "extracted_metadata": {
#         "sha1": "c4014bb3fe6f1fb5ff5fe4a1eb34df348f0c0e18",
#         "filename": "n",
#         "file_type": "json"
#       },
#       "text": "Three years after the destruction of the Death Star, the Rebel Alliance has been driven from their former base on Yavin IV by the Galactic Empire. The Rebels, led by Princess Leia, have set up their new base on the ice planet Hoth. The Imperial fleet, led by Darth Vader, continues to hunt for the Rebels\u2019 new base by dispatching probe droids across the galaxy.",
#       "metadata": {
#         "title": "Star Wars: Episode V - The Empire Strikes Back"
#       },
#       "enriched_text": {
#         "sentiment": {
#           "document": {
#             "score": -0.75041,
#             "label": "negative"
#           }
#         },
#         "entities": [
#           {
#             "count": 3,
#             "sentiment": {
#               "score": 0.238317,
#               "label": "positive"
#             },
#             "text": "Rebel Alliance",
#             "relevance": 0.807131,
#             "type": "Organization",
#             "disambiguation": {
#               "subtype": [],
#               "name": "Rebel Alliance",
#               "dbpedia_resource": "http://dbpedia.org/resource/Rebel_Alliance"
#             }
#           },
#           {
#             "count": 1,
#             "sentiment": {
#               "score": -0.292477,
#               "label": "negative"
#             },
#             "text": "Darth Vader",
#             "relevance": 0.59847,
#             "type": "Person"
#           },
#           {
#             "count": 1,
#             "sentiment": {
#               "score": 0.425247,
#               "label": "positive"
#             },
#             "text": "Princess Leia",
#             "relevance": 0.580596,
#             "type": "Person"
#           },
#           {
#             "count": 1,
#             "sentiment": {
#               "score": 0,
#               "label": "neutral"
#             },
#             "text": "Galactic Empire",
#             "relevance": 0.570897,
#             "type": "Facility"
#           },
#           {
#             "count": 1,
#             "sentiment": {
#               "score": 0,
#               "label": "neutral"
#             },
#             "text": "Three years",
#             "relevance": 0.570897,
#             "type": "Quantity"
#           }
#         ],
#         "concepts": [
#           {
#             "text": "Star Wars Episode IV: A New Hope",
#             "relevance": 0.947403,
#             "dbpedia_resource": "http://dbpedia.org/resource/Star_Wars_Episode_IV:_A_New_Hope"
#           },
#           {
#             "text": "Darth Vader",
#             "relevance": 0.89423,
#             "dbpedia_resource": "http://dbpedia.org/resource/Darth_Vader"
#           },
#           {
#             "text": "Rebel Alliance",
#             "relevance": 0.894131,
#             "dbpedia_resource": "http://dbpedia.org/resource/Rebel_Alliance"
#           },
#           {
#             "text": "Star Wars Episode V: The Empire Strikes Back",
#             "relevance": 0.811135,
#             "dbpedia_resource": "http://dbpedia.org/resource/Star_Wars_Episode_V:_The_Empire_Strikes_Back"
#           },
#           {
#             "text": "Star Wars Episode VI: Return of the Jedi",
#             "relevance": 0.769414,
#             "dbpedia_resource": "http://dbpedia.org/resource/Star_Wars_Episode_VI:_Return_of_the_Jedi"
#           },
#           {
#             "text": "Luke Skywalker",
#             "relevance": 0.745122,
#             "dbpedia_resource": "http://dbpedia.org/resource/Luke_Skywalker"
#           },
#           {
#             "text": "Star Wars",
#             "relevance": 0.714044,
#             "dbpedia_resource": "http://dbpedia.org/resource/Star_Wars"
#           },
#           {
#             "text": "Padm\u00e9 Amidala",
#             "relevance": 0.661661,
#             "dbpedia_resource": "http://dbpedia.org/resource/Padm\u00e9_Amidala"
#           }
#         ],
#         "categories": [
#           {
#             "score": 0.604847,
#             "label": "/law, govt and politics/politics"
#           },
#           {
#             "score": 0.579427,
#             "label": "/travel/transports"
#           },
#           {
#             "score": 0.572844,
#             "label": "/art and entertainment/movies"
#           }
#         ]
#       }
#     },
#     {
#       "id": "94e1a242-936a-46c1-bcfb-79a43a864442",
#       "result_metadata": {
#         "score": 1
#       },
#       "extracted_metadata": {
#         "sha1": "0a47755f3ca236ea62a32f9d3f08986b1b9296e0",
#         "filename": "n",
#         "file_type": "json"
#       },
#       "text": "Vader goes back on his agreement with Lando to let Leia and Chewbacca stay in Cloud City and instead, takes them into custody. He intends to hold Luke in suspended animation in a block of carbonite for delivery to the Emperor. To test this process, he selects Han to be frozen against the protests of Fett, who fears he will lose his bounty. Vader hands the frozen Han over to Fett, who intends to leave for Tatooine to deliver Han to Jabba the Hutt and claim the bounty on Solo. Lando, who was forced into cooperating with the Empire, initiates an escape and frees Leia and the others. They then try to save Han but are too late and unable to stop Fett as he departs on his ship. They fight their way back to the Falcon and flee Cloud City.",
#       "metadata": {
#         "title": "Star Wars: Episode V - The Empire Strikes Back"
#       },
#       "enriched_text": {
#         "sentiment": {
#           "document": {
#             "score": -0.847888,
#             "label": "negative"
#           }
#         },
#         "entities": [
#           {
#             "count": 5,
#             "sentiment": {
#               "score": -0.479122,
#               "label": "negative"
#             },
#             "text": "Fett",
#             "relevance": 0.955496,
#             "type": "Person"
#           },
#           {
#             "count": 3,
#             "sentiment": {
#               "score": -0.564691,
#               "label": "negative"
#             },
#             "text": "Han",
#             "relevance": 0.948567,
#             "type": "Person"
#           },
#           {
#             "count": 2,
#             "sentiment": {
#               "score": -0.562213,
#               "label": "negative"
#             },
#             "text": "Cloud City",
#             "relevance": 0.563967,
#             "type": "Location",
#             "disambiguation": {
#               "subtype": [
#                 "City"
#               ]
#             }
#           },
#           {
#             "count": 2,
#             "sentiment": {
#               "score": -0.794134,
#               "label": "negative"
#             },
#             "text": "Lando",
#             "relevance": 0.563719,
#             "type": "Person"
#           },
#           {
#             "count": 2,
#             "sentiment": {
#               "score": -0.794134,
#               "label": "negative"
#             },
#             "text": "Leia",
#             "relevance": 0.525719,
#             "type": "Person"
#           },
#           {
#             "count": 1,
#             "sentiment": {
#               "score": -0.709305,
#               "label": "negative"
#             },
#             "text": "Luke",
#             "relevance": 0.28476,
#             "type": "Person"
#           },
#           {
#             "count": 1,
#             "sentiment": {
#               "score": -0.564691,
#               "label": "negative"
#             },
#             "text": "Tatooine",
#             "relevance": 0.279449,
#             "type": "Location",
#             "disambiguation": {
#               "subtype": [
#                 "City"
#               ]
#             }
#           },
#           {
#             "count": 1,
#             "sentiment": {
#               "score": -0.709305,
#               "label": "negative"
#             },
#             "text": "carbonite",
#             "relevance": 0.259551,
#             "type": "Company"
#           }
#         ],
#         "concepts": [
#           {
#             "text": "Star Wars Episode VI: Return of the Jedi",
#             "relevance": 0.96261,
#             "dbpedia_resource": "http://dbpedia.org/resource/Star_Wars_Episode_VI:_Return_of_the_Jedi"
#           },
#           {
#             "text": "Star Wars Episode V: The Empire Strikes Back",
#             "relevance": 0.834401,
#             "dbpedia_resource": "http://dbpedia.org/resource/Star_Wars_Episode_V:_The_Empire_Strikes_Back"
#           },
#           {
#             "text": "Darth Vader",
#             "relevance": 0.799163,
#             "dbpedia_resource": "http://dbpedia.org/resource/Darth_Vader"
#           },
#           {
#             "text": "Star Wars Episode IV: A New Hope",
#             "relevance": 0.795979,
#             "dbpedia_resource": "http://dbpedia.org/resource/Star_Wars_Episode_IV:_A_New_Hope"
#           },
#           {
#             "text": "Jabba the Hutt",
#             "relevance": 0.775692,
#             "dbpedia_resource": "http://dbpedia.org/resource/Jabba_the_Hutt"
#           },
#           {
#             "text": "Star Wars",
#             "relevance": 0.774272,
#             "dbpedia_resource": "http://dbpedia.org/resource/Star_Wars"
#           },
#           {
#             "text": "Han Solo",
#             "relevance": 0.761185,
#             "dbpedia_resource": "http://dbpedia.org/resource/Han_Solo"
#           },
#           {
#             "text": "Luke Skywalker",
#             "relevance": 0.731425,
#             "dbpedia_resource": "http://dbpedia.org/resource/Luke_Skywalker"
#           }
#         ],
#         "categories": [
#           {
#             "score": 0.566104,
#             "label": "/art and entertainment/movies"
#           },
#           {
#             "score": 0.557839,
#             "label": "/art and entertainment/movies and tv/movies"
#           },
#           {
#             "score": 0.548275,
#             "label": "/travel/transports/sea travel"
#           }
#         ]
#       }
#     },
#     {
#       "id": "1d0117f3-de8e-4b81-a1d1-ed2319a6fe4f",
#       "result_metadata": {
#         "score": 1
#       },
#       "extracted_metadata": {
#         "sha1": "483a5d301dbe9b91822d94da26190e07fe216e14",
#         "filename": "n",
#         "file_type": "json"
#       },
#       "text": "After arriving at Cloud City, and engaging in a brief confrontation with Boba Fett, Luke ultimately falls into Vader's trap. The two engage in a lightsaber duel that leads them over the city's central air shaft where, as his mentors warned, Luke proves to be no match for Vader who severs Luke's right hand, causing him to lose his weapon. After Luke refuses to join Vader against the Emperor, Vader reveals that he is Luke's father, Anakin Skywalker. Horrified by the truth, Luke throws himself off the bridge and is pulled into an air shaft. He is ejected beneath the floating city but is able to grab onto an antenna. He makes a desperate telepathic plea to Leia, who senses it and persuades Lando to return for him in the Falcon. After Luke is brought on board, they are chased by TIE fighters but R2-D2 reactivates the Falcon's hyperdrive, allowing them to escape.",
#       "metadata": {
#         "title": "Star Wars: Episode V - The Empire Strikes Back"
#       },
#       "enriched_text": {
#         "sentiment": {
#           "document": {
#             "score": -0.792059,
#             "label": "negative"
#           }
#         },
#         "entities": [
#           {
#             "count": 12,
#             "sentiment": {
#               "score": -0.312581,
#               "label": "negative"
#             },
#             "text": "Luke",
#             "relevance": 0.941474,
#             "type": "Person"
#           },
#           {
#             "count": 6,
#             "sentiment": {
#               "score": -0.58801,
#               "label": "negative"
#             },
#             "text": "Vader",
#             "relevance": 0.483592,
#             "type": "Person"
#           },
#           {
#             "count": 2,
#             "sentiment": {
#               "score": -0.578887,
#               "label": "negative"
#             },
#             "text": "Cloud City",
#             "relevance": 0.271107,
#             "type": "Company"
#           },
#           {
#             "count": 1,
#             "sentiment": {
#               "score": 0.485384,
#               "label": "positive"
#             },
#             "text": "Boba Fett",
#             "relevance": 0.194638,
#             "type": "Person"
#           },
#           {
#             "count": 1,
#             "sentiment": {
#               "score": -0.760332,
#               "label": "negative"
#             },
#             "text": "Anakin Skywalker",
#             "relevance": 0.156578,
#             "type": "Person"
#           },
#           {
#             "count": 2,
#             "sentiment": {
#               "score": 0,
#               "label": "neutral"
#             },
#             "text": "Lando",
#             "relevance": 0.141476,
#             "type": "Person"
#           },
#           {
#             "count": 1,
#             "sentiment": {
#               "score": 0.581439,
#               "label": "positive"
#             },
#             "text": "Leia",
#             "relevance": 0.141115,
#             "type": "Person"
#           }
#         ],
#         "concepts": [
#           {
#             "text": "Star Wars Episode VI: Return of the Jedi",
#             "relevance": 0.956253,
#             "dbpedia_resource": "http://dbpedia.org/resource/Star_Wars_Episode_VI:_Return_of_the_Jedi"
#           },
#           {
#             "text": "Darth Vader",
#             "relevance": 0.903459,
#             "dbpedia_resource": "http://dbpedia.org/resource/Darth_Vader"
#           },
#           {
#             "text": "Obi-Wan Kenobi",
#             "relevance": 0.797313,
#             "dbpedia_resource": "http://dbpedia.org/resource/Obi-Wan_Kenobi"
#           },
#           {
#             "text": "Star Wars Episode V: The Empire Strikes Back",
#             "relevance": 0.778385,
#             "dbpedia_resource": "http://dbpedia.org/resource/Star_Wars_Episode_V:_The_Empire_Strikes_Back"
#           },
#           {
#             "text": "Star Wars",
#             "relevance": 0.724052,
#             "dbpedia_resource": "http://dbpedia.org/resource/Star_Wars"
#           },
#           {
#             "text": "C-3PO",
#             "relevance": 0.722281,
#             "dbpedia_resource": "http://dbpedia.org/resource/C-3PO"
#           },
#           {
#             "text": "Anakin Skywalker",
#             "relevance": 0.718351,
#             "dbpedia_resource": "http://dbpedia.org/resource/Anakin_Skywalker"
#           },
#           {
#             "text": "Luke Skywalker",
#             "relevance": 0.705331,
#             "dbpedia_resource": "http://dbpedia.org/resource/Luke_Skywalker"
#           }
#         ],
#         "categories": [
#           {
#             "score": 0.60363,
#             "label": "/sports/wrestling"
#           },
#           {
#             "score": 0.602183,
#             "label": "/travel/transports"
#           },
#           {
#             "score": 0.602111,
#             "label": "/art and entertainment/shows and events"
#           }
#         ]
#       }
#     },
#     {
#       "id": "9582926a-93bd-4918-ac75-7bc7edd9b8d9",
#       "result_metadata": {
#         "score": 1
#       },
#       "extracted_metadata": {
#         "sha1": "de70c9b90d0c1d60fbabdaffae17b362e3cb2188",
#         "filename": "sample.html",
#         "file_type": "html",
#         "title": "Star Wars: Episode IV - A New Hope (Opening Crawl)"
#       },
#       "html": "<?xml version='1.0' encoding='UTF-8' standalone='yes'?><html>\n<head>\n    <meta content=\"text/html; charset=UTF-8\" http-equiv=\"Content-Type\"/>\n    <title>Star Wars: Episode IV - A New Hope (Opening Crawl)</title>\n\n</head>\n<body>\n\n    <article>\n        <h1>Star Wars: Episode IV - A New Hope (Opening Crawl)</h1>\n        <p>\n            It is a period of civil war. Rebel spaceships, striking from a hidden base, have won their first victory against the evil Galactic Empire.\n        </p><p>\n            During the battle, Rebel spies managed to steal secret plans to the Empire's ultimate weapon, the DEATH STAR, an armored space station with enough power to destroy an entire planet.\n        </p><p>\n            Pursued by the Empire's sinister agents, Princess Leia races home aboard her starship, custodian of the stolen plans that can save her people and restore freedom to the galaxy...\n        </p>\n    </article>\n</body></html>",
#       "text": "Star Wars: Episode IV - A New Hope (Opening Crawl)\n\nStar Wars: Episode IV - A New Hope (Opening Crawl)\n\nIt is a period of civil war. Rebel spaceships, striking from a hidden base, have won their first victory against the evil Galactic Empire.\n\nDuring the battle, Rebel spies managed to steal secret plans to the Empire's ultimate weapon, the DEATH STAR, an armored space station with enough power to destroy an entire planet.\n\nPursued by the Empire's sinister agents, Princess Leia races home aboard her starship, custodian of the stolen plans that can save her people and restore freedom to the galaxy...",
#       "enriched_text": {
#         "sentiment": {
#           "document": {
#             "score": 0.35128,
#             "label": "positive"
#           }
#         },
#         "entities": [],
#         "concepts": [
#           {
#             "text": "Star Wars Episode IV: A New Hope",
#             "relevance": 0.98887,
#             "dbpedia_resource": "http://dbpedia.org/resource/Star_Wars_Episode_IV:_A_New_Hope"
#           },
#           {
#             "text": "Star Wars",
#             "relevance": 0.985705,
#             "dbpedia_resource": "http://dbpedia.org/resource/Star_Wars"
#           },
#           {
#             "text": "Rebel Alliance",
#             "relevance": 0.90639,
#             "dbpedia_resource": "http://dbpedia.org/resource/Rebel_Alliance"
#           },
#           {
#             "text": "Luke Skywalker",
#             "relevance": 0.805771,
#             "dbpedia_resource": "http://dbpedia.org/resource/Luke_Skywalker"
#           },
#           {
#             "text": "Star Wars Episode V: The Empire Strikes Back",
#             "relevance": 0.801062,
#             "dbpedia_resource": "http://dbpedia.org/resource/Star_Wars_Episode_V:_The_Empire_Strikes_Back"
#           },
#           {
#             "text": "Darth Vader",
#             "relevance": 0.777337,
#             "dbpedia_resource": "http://dbpedia.org/resource/Darth_Vader"
#           },
#           {
#             "text": "Star Wars Episode VI: Return of the Jedi",
#             "relevance": 0.77159,
#             "dbpedia_resource": "http://dbpedia.org/resource/Star_Wars_Episode_VI:_Return_of_the_Jedi"
#           },
#           {
#             "text": "Grand Moff Tarkin",
#             "relevance": 0.748553,
#             "dbpedia_resource": "http://dbpedia.org/resource/Grand_Moff_Tarkin"
#           }
#         ],
#         "categories": [
#           {
#             "score": 0.70337,
#             "label": "/society/unrest and war"
#           },
#           {
#             "score": 0.680538,
#             "label": "/travel/transports/sea travel"
#           },
#           {
#             "score": 0.631002,
#             "label": "/art and entertainment/movies and tv/movies"
#           }
#         ]
#       }
#     },
#     {
#       "id": "ca12cc92-79b0-4f14-8203-e7ad52e2cda1",
#       "result_metadata": {
#         "score": 1
#       },
#       "extracted_metadata": {
#         "sha1": "7e8cf0b6e7d6d9d24d6802d0ab969f4f42a38f6b",
#         "filename": "n",
#         "file_type": "json"
#       },
#       "text": "Obi-Wan's investigation leads him to the remote ocean planet Kamino, where he discovers an army of clones is being produced for the Republic, with bounty hunter Jango Fett serving as their genetic template. Obi-Wan deduces Jango to be the bounty hunter he is seeking, and follows him and his clone son, Boba, to the desert planet Geonosis via a homing beacon placed on their ship, the Slave I. Meanwhile, Anakin becomes troubled by premonitions of his mother, Shmi, in pain, and travels to Tatooine with Padm\u00e9 to save her. They meet Owen Lars, Anakin's stepbrother and the son of Shmi's new husband, Cliegg Lars. Cliegg tells Anakin that Shmi was abducted by Tusken Raiders weeks earlier and is likely dead. Determined to find her, Anakin ventures out and finds Shmi at the Tusken campsite, where she dies in Anakin's arms. Enraged, Anakin massacres the Tuskens and returns to the Lars homestead with Shmi's body. After revealing his deed to Padm\u00e9, Anakin says that he wants to prevent death.",
#       "metadata": {
#         "title": "Star Wars: Episode II - Attack of the Clones"
#       },
#       "enriched_text": {
#         "sentiment": {
#           "document": {
#             "score": -0.701065,
#             "label": "negative"
#           }
#         },
#         "entities": [
#           {
#             "count": 8,
#             "sentiment": {
#               "score": -0.585352,
#               "label": "negative"
#             },
#             "text": "Anakin",
#             "relevance": 0.938404,
#             "type": "Person"
#           },
#           {
#             "count": 7,
#             "sentiment": {
#               "score": -0.524551,
#               "label": "negative"
#             },
#             "text": "Shmi",
#             "relevance": 0.832747,
#             "type": "Person"
#           },
#           {
#             "count": 3,
#             "sentiment": {
#               "score": -0.551205,
#               "label": "negative"
#             },
#             "text": "Cliegg Lars",
#             "relevance": 0.32508,
#             "type": "Person"
#           },
#           {
#             "count": 1,
#             "sentiment": {
#               "score": 0.504938,
#               "label": "positive"
#             },
#             "text": "Jango Fett",
#             "relevance": 0.254378,
#             "type": "Person"
#           },
#           {
#             "count": 3,
#             "sentiment": {
#               "score": 0,
#               "label": "neutral"
#             },
#             "text": "Obi-Wan",
#             "relevance": 0.226119,
#             "type": "Person"
#           },
#           {
#             "count": 1,
#             "sentiment": {
#               "score": -0.396324,
#               "label": "negative"
#             },
#             "text": "Tusken Raiders",
#             "relevance": 0.20842,
#             "type": "Organization"
#           },
#           {
#             "count": 3,
#             "sentiment": {
#               "score": 0,
#               "label": "neutral"
#             },
#             "text": "Padm\u00e9",
#             "relevance": 0.192448,
#             "type": "Person"
#           },
#           {
#             "count": 1,
#             "sentiment": {
#               "score": -0.705339,
#               "label": "negative"
#             },
#             "text": "Tusken",
#             "relevance": 0.172401,
#             "type": "Location",
#             "disambiguation": {
#               "subtype": [
#                 "City"
#               ]
#             }
#           },
#           {
#             "count": 1,
#             "sentiment": {
#               "score": 0.393253,
#               "label": "positive"
#             },
#             "text": "Boba",
#             "relevance": 0.156956,
#             "type": "Person"
#           },
#           {
#             "count": 1,
#             "sentiment": {
#               "score": 0,
#               "label": "neutral"
#             },
#             "text": "Geonosis",
#             "relevance": 0.131101,
#             "type": "Location",
#             "disambiguation": {
#               "subtype": [
#                 "City"
#               ]
#             }
#           }
#         ],
#         "concepts": [
#           {
#             "text": "Star Wars Episode II: Attack of the Clones",
#             "relevance": 0.969534,
#             "dbpedia_resource": "http://dbpedia.org/resource/Star_Wars_Episode_II:_Attack_of_the_Clones"
#           },
#           {
#             "text": "Jango Fett",
#             "relevance": 0.942901,
#             "dbpedia_resource": "http://dbpedia.org/resource/Jango_Fett"
#           },
#           {
#             "text": "Boba Fett",
#             "relevance": 0.788025,
#             "dbpedia_resource": "http://dbpedia.org/resource/Boba_Fett"
#           },
#           {
#             "text": "Obi-Wan Kenobi",
#             "relevance": 0.781814,
#             "dbpedia_resource": "http://dbpedia.org/resource/Obi-Wan_Kenobi"
#           },
#           {
#             "text": "Tatooine",
#             "relevance": 0.615965,
#             "dbpedia_resource": "http://dbpedia.org/resource/Tatooine"
#           },
#           {
#             "text": "Bounty hunter",
#             "relevance": 0.609987,
#             "dbpedia_resource": "http://dbpedia.org/resource/Bounty_hunter"
#           },
#           {
#             "text": "Star Wars characters",
#             "relevance": 0.606362,
#             "dbpedia_resource": "http://dbpedia.org/resource/Star_Wars_characters"
#           },
#           {
#             "text": "Temuera Morrison",
#             "relevance": 0.595906,
#             "dbpedia_resource": "http://dbpedia.org/resource/Temuera_Morrison"
#           }
#         ],
#         "categories": [
#           {
#             "score": 0.576414,
#             "label": "/art and entertainment/movies"
#           },
#           {
#             "score": 0.57017,
#             "label": "/law, govt and politics/politics"
#           },
#           {
#             "score": 0.570038,
#             "label": "/style and fashion/body art"
#           }
#         ]
#       }
#     },
#     {
#       "id": "5b92c93c-f1bf-4271-8ae6-55ef498e2a16",
#       "result_metadata": {
#         "score": 1
#       },
#       "extracted_metadata": {
#         "sha1": "2518058f8fe76c492664a02d668d82111c1a79ed",
#         "filename": "n",
#         "file_type": "json"
#       },
#       "text": "Starkiller Base fires and destroys the Republic capital and a portion of its fleet. The First Order attacks Takodana in search of BB-8. Han, Chewbacca, and Finn are saved by Resistance X-wing fighters led by Poe, who survived the earlier crash. Leia arrives at Takodana with C-3PO and reunites with Han and Chewbacca. Meanwhile, Ren captures Rey and takes her to Starkiller Base. However, when he interrogates her about the map, she is able to resist his mind-reading attempts. Discovering she can use the Force, she escapes using a Jedi mind trick on a nearby guard.",
#       "metadata": {
#         "title": "Star Wars: Episode VII - The Force Awakens"
#       },
#       "enriched_text": {
#         "sentiment": {
#           "document": {
#             "score": 0.670488,
#             "label": "positive"
#           }
#         },
#         "entities": [
#           {
#             "count": 3,
#             "sentiment": {
#               "score": 0,
#               "label": "neutral"
#             },
#             "text": "Han",
#             "relevance": 0.829854,
#             "type": "Person"
#           },
#           {
#             "count": 6,
#             "sentiment": {
#               "score": 0,
#               "label": "neutral"
#             },
#             "text": "Rey",
#             "relevance": 0.464344,
#             "type": "Person"
#           },
#           {
#             "count": 2,
#             "sentiment": {
#               "score": -0.320402,
#               "label": "negative"
#             },
#             "text": "Takodana",
#             "relevance": 0.459415,
#             "type": "Location",
#             "disambiguation": {
#               "subtype": [
#                 "City"
#               ]
#             }
#           },
#           {
#             "count": 1,
#             "sentiment": {
#               "score": 0,
#               "label": "neutral"
#             },
#             "text": "Starkiller Base",
#             "relevance": 0.4491,
#             "type": "GeographicFeature"
#           },
#           {
#             "count": 1,
#             "sentiment": {
#               "score": 0,
#               "label": "neutral"
#             },
#             "text": "Finn",
#             "relevance": 0.332172,
#             "type": "Person"
#           },
#           {
#             "count": 1,
#             "sentiment": {
#               "score": 0,
#               "label": "neutral"
#             },
#             "text": "Poe",
#             "relevance": 0.326253,
#             "type": "Person"
#           },
#           {
#             "count": 1,
#             "sentiment": {
#               "score": 0,
#               "label": "neutral"
#             },
#             "text": "Ren",
#             "relevance": 0.319759,
#             "type": "Person"
#           }
#         ],
#         "concepts": [
#           {
#             "text": "Luke Skywalker",
#             "relevance": 0.963566,
#             "dbpedia_resource": "http://dbpedia.org/resource/Luke_Skywalker"
#           },
#           {
#             "text": "Star Wars",
#             "relevance": 0.910631,
#             "dbpedia_resource": "http://dbpedia.org/resource/Star_Wars"
#           },
#           {
#             "text": "Star Wars Episode IV: A New Hope",
#             "relevance": 0.906126,
#             "dbpedia_resource": "http://dbpedia.org/resource/Star_Wars_Episode_IV:_A_New_Hope"
#           },
#           {
#             "text": "Darth Vader",
#             "relevance": 0.900991,
#             "dbpedia_resource": "http://dbpedia.org/resource/Darth_Vader"
#           },
#           {
#             "text": "Star Wars Episode III: Revenge of the Sith",
#             "relevance": 0.77562,
#             "dbpedia_resource": "http://dbpedia.org/resource/Star_Wars_Episode_III:_Revenge_of_the_Sith"
#           },
#           {
#             "text": "Obi-Wan Kenobi",
#             "relevance": 0.765912,
#             "dbpedia_resource": "http://dbpedia.org/resource/Obi-Wan_Kenobi"
#           },
#           {
#             "text": "Rebel Alliance",
#             "relevance": 0.750413,
#             "dbpedia_resource": "http://dbpedia.org/resource/Rebel_Alliance"
#           },
#           {
#             "text": "Yoda",
#             "relevance": 0.676399,
#             "dbpedia_resource": "http://dbpedia.org/resource/Yoda"
#           }
#         ],
#         "categories": [
#           {
#             "score": 0.612977,
#             "label": "/travel/transports"
#           },
#           {
#             "score": 0.581685,
#             "label": "/society/unrest and war"
#           },
#           {
#             "score": 0.571102,
#             "label": "/travel/transports/sea travel"
#           }
#         ]
#       }
#     },
#     {
#       "id": "23d77d97-9021-4428-8cea-e075312426ca",
#       "result_metadata": {
#         "score": 1
#       },
#       "extracted_metadata": {
#         "sha1": "49ae61effe80299160a28bbd1477d1a3fed668c3",
#         "filename": "n",
#         "file_type": "json"
#       },
#       "text": "Three years after the the start of the Clone Wars between the Galactic Republic and the Confederacy of Independent Systems, war has gripped the galaxy. During a space battle over the planet Coruscant, Jedi Knights Obi-Wan Kenobi and Anakin Skywalker lead a mission to rescue the kidnapped Supreme Chancellor Palpatine from Separatist commander General Grievous. After infiltrating Grievous's flagship, the Jedi battle Count Dooku. Anakin subdues Dooku, and on Palpatine's urging, executes him. Grievous flees the battle-torn cruiser, which the Jedi crash-land on Coruscant. There, Anakin reunites with his wife, Padm\u00e9 Amidala, who reveals she is pregnant. While initially excited, Anakin begins to have prophetic visions of Padm\u00e9 dying in childbirth, and his worry steadily grows.",
#       "metadata": {
#         "title": "Star Wars: Episode III - Revenge of the Sith"
#       },
#       "enriched_text": {
#         "sentiment": {
#           "document": {
#             "score": -0.390665,
#             "label": "negative"
#           }
#         },
#         "entities": [
#           {
#             "count": 3,
#             "sentiment": {
#               "score": -0.471802,
#               "label": "negative"
#             },
#             "text": "Anakin Skywalker",
#             "relevance": 0.91224,
#             "type": "Person"
#           },
#           {
#             "count": 3,
#             "sentiment": {
#               "score": -0.429983,
#               "label": "negative"
#             },
#             "text": "Supreme Chancellor Palpatine",
#             "relevance": 0.717952,
#             "type": "Person"
#           },
#           {
#             "count": 3,
#             "sentiment": {
#               "score": 0,
#               "label": "neutral"
#             },
#             "text": "Padm\u00e9 Amidala",
#             "relevance": 0.366826,
#             "type": "Person"
#           },
#           {
#             "count": 1,
#             "sentiment": {
#               "score": -0.493018,
#               "label": "negative"
#             },
#             "text": "Confederacy of Independent Systems",
#             "relevance": 0.313719,
#             "type": "Organization"
#           },
#           {
#             "count": 1,
#             "sentiment": {
#               "score": 0,
#               "label": "neutral"
#             },
#             "text": "commander",
#             "relevance": 0.233588,
#             "type": "JobTitle"
#           },
#           {
#             "count": 1,
#             "sentiment": {
#               "score": 0,
#               "label": "neutral"
#             },
#             "text": "Three years",
#             "relevance": 0.233588,
#             "type": "Quantity"
#           }
#         ],
#         "concepts": [
#           {
#             "text": "Palpatine",
#             "relevance": 0.930923,
#             "dbpedia_resource": "http://dbpedia.org/resource/Palpatine"
#           },
#           {
#             "text": "Anakin Skywalker",
#             "relevance": 0.915691,
#             "dbpedia_resource": "http://dbpedia.org/resource/Anakin_Skywalker"
#           },
#           {
#             "text": "Obi-Wan Kenobi",
#             "relevance": 0.829859,
#             "dbpedia_resource": "http://dbpedia.org/resource/Obi-Wan_Kenobi"
#           },
#           {
#             "text": "Star Wars Episode III: Revenge of the Sith",
#             "relevance": 0.813145,
#             "dbpedia_resource": "http://dbpedia.org/resource/Star_Wars_Episode_III:_Revenge_of_the_Sith"
#           },
#           {
#             "text": "Yoda",
#             "relevance": 0.801147,
#             "dbpedia_resource": "http://dbpedia.org/resource/Yoda"
#           },
#           {
#             "text": "Clone Wars",
#             "relevance": 0.769773,
#             "dbpedia_resource": "http://dbpedia.org/resource/Clone_Wars_(Star_Wars)"
#           },
#           {
#             "text": "Mace Windu",
#             "relevance": 0.748672,
#             "dbpedia_resource": "http://dbpedia.org/resource/Mace_Windu"
#           },
#           {
#             "text": "Star Wars Episode II: Attack of the Clones",
#             "relevance": 0.747519,
#             "dbpedia_resource": "http://dbpedia.org/resource/Star_Wars_Episode_II:_Attack_of_the_Clones"
#           }
#         ],
#         "categories": [
#           {
#             "score": 0.615547,
#             "label": "/law, govt and politics/politics"
#           },
#           {
#             "score": 0.571756,
#             "label": "/law, govt and politics/government/heads of state"
#           },
#           {
#             "score": 0.563305,
#             "label": "/art and entertainment/comics and animation/comics"
#           }
#         ]
#       }
#     },
#     {
#       "id": "84b13db4-750a-47db-96ac-632f77cae6bb",
#       "result_metadata": {
#         "score": 1
#       },
#       "extracted_metadata": {
#         "sha1": "5e25cb2202a51343431f6775252a4652bae061ec",
#         "filename": "n",
#         "file_type": "json"
#       },
#       "text": "On the asteroid Polis Massa, Obi-Wan regroups with Yoda and Padm\u00e9 gives birth to twins Luke and Leia before dying. A funeral is held for Padm\u00e9 on Naboo. On Mustafar, Palpatine finds a severely burnt Vader still alive. After returning to Coruscant, Vader's mutilated body is amputated and covered in a black armored suit. Palpatine explains to Vader that he killed Padm\u00e9 in his anger. Meanwhile, Obi-Wan and Yoda decide to conceal the twins from the Sith, as they are the galaxy's only hope for freedom. Yoda exiles himself to the planet Dagobah, while Vader and the Emperor oversee the construction of a superstation, the Death Star. Bail Organa adopts Leia as his own daughter and takes her to Alderaan, while Obi-Wan delivers Luke to his step-family Owen and Beru Lars on Tatooine, where Obi-Wan intends to watch over Luke until the time is right to challenge the Empire.",
#       "metadata": {
#         "title": "Star Wars: Episode III - Revenge of the Sith"
#       },
#       "enriched_text": {
#         "sentiment": {
#           "document": {
#             "score": -0.704862,
#             "label": "negative"
#           }
#         },
#         "entities": [
#           {
#             "count": 5,
#             "sentiment": {
#               "score": -0.648741,
#               "label": "negative"
#             },
#             "text": "Vader",
#             "relevance": 0.875983,
#             "type": "Person"
#           },
#           {
#             "count": 4,
#             "sentiment": {
#               "score": -0.253689,
#               "label": "negative"
#             },
#             "text": "Yoda",
#             "relevance": 0.615411,
#             "type": "Person"
#           },
#           {
#             "count": 3,
#             "sentiment": {
#               "score": 0.674915,
#               "label": "positive"
#             },
#             "text": "Luke",
#             "relevance": 0.474405,
#             "type": "Person"
#           },
#           {
#             "count": 1,
#             "sentiment": {
#               "score": 0,
#               "label": "neutral"
#             },
#             "text": "Obi-Wan",
#             "relevance": 0.453136,
#             "type": "Person"
#           },
#           {
#             "count": 2,
#             "sentiment": {
#               "score": -0.651221,
#               "label": "negative"
#             },
#             "text": "Palpatine",
#             "relevance": 0.435453,
#             "type": "Person"
#           },
#           {
#             "count": 2,
#             "sentiment": {
#               "score": 0.153243,
#               "label": "positive"
#             },
#             "text": "Leia",
#             "relevance": 0.416575,
#             "type": "Person"
#           },
#           {
#             "count": 1,
#             "sentiment": {
#               "score": 0,
#               "label": "neutral"
#             },
#             "text": "Polis Massa",
#             "relevance": 0.349812,
#             "type": "Person"
#           },
#           {
#             "count": 2,
#             "sentiment": {
#               "score": -0.59695,
#               "label": "negative"
#             },
#             "text": "Padm\u00e9",
#             "relevance": 0.326848,
#             "type": "Person"
#           },
#           {
#             "count": 1,
#             "sentiment": {
#               "score": 0,
#               "label": "neutral"
#             },
#             "text": "Beru Lars",
#             "relevance": 0.269581,
#             "type": "Person"
#           },
#           {
#             "count": 1,
#             "sentiment": {
#               "score": -0.368428,
#               "label": "negative"
#             },
#             "text": "Alderaan",
#             "relevance": 0.25204,
#             "type": "Location",
#             "disambiguation": {
#               "subtype": [
#                 "City"
#               ]
#             }
#           },
#           {
#             "count": 1,
#             "sentiment": {
#               "score": -0.368428,
#               "label": "negative"
#             },
#             "text": "Organa",
#             "relevance": 0.24868,
#             "type": "Person",
#             "disambiguation": {
#               "subtype": [],
#               "name": "Organa",
#               "dbpedia_resource": "http://dbpedia.org/resource/Organa"
#             }
#           },
#           {
#             "count": 1,
#             "sentiment": {
#               "score": 0,
#               "label": "neutral"
#             },
#             "text": "Mustafar",
#             "relevance": 0.198025,
#             "type": "Person"
#           },
#           {
#             "count": 1,
#             "sentiment": {
#               "score": 0,
#               "label": "neutral"
#             },
#             "text": "Owen",
#             "relevance": 0.179314,
#             "type": "Person"
#           }
#         ],
#         "concepts": [
#           {
#             "text": "Star Wars Episode III: Revenge of the Sith",
#             "relevance": 0.965363,
#             "dbpedia_resource": "http://dbpedia.org/resource/Star_Wars_Episode_III:_Revenge_of_the_Sith"
#           },
#           {
#             "text": "Star Wars",
#             "relevance": 0.891434,
#             "dbpedia_resource": "http://dbpedia.org/resource/Star_Wars"
#           },
#           {
#             "text": "Luke Skywalker",
#             "relevance": 0.809195,
#             "dbpedia_resource": "http://dbpedia.org/resource/Luke_Skywalker"
#           },
#           {
#             "text": "Star Wars Episode VI: Return of the Jedi",
#             "relevance": 0.787677,
#             "dbpedia_resource": "http://dbpedia.org/resource/Star_Wars_Episode_VI:_Return_of_the_Jedi"
#           },
#           {
#             "text": "Darth Vader",
#             "relevance": 0.778165,
#             "dbpedia_resource": "http://dbpedia.org/resource/Darth_Vader"
#           },
#           {
#             "text": "Star Wars Episode II: Attack of the Clones",
#             "relevance": 0.753415,
#             "dbpedia_resource": "http://dbpedia.org/resource/Star_Wars_Episode_II:_Attack_of_the_Clones"
#           },
#           {
#             "text": "Obi-Wan Kenobi",
#             "relevance": 0.752269,
#             "dbpedia_resource": "http://dbpedia.org/resource/Obi-Wan_Kenobi"
#           },
#           {
#             "text": "Anakin Skywalker",
#             "relevance": 0.71621,
#             "dbpedia_resource": "http://dbpedia.org/resource/Anakin_Skywalker"
#           }
#         ],
#         "categories": [
#           {
#             "score": 0.587854,
#             "label": "/law, govt and politics/government/heads of state"
#           },
#           {
#             "score": 0.578131,
#             "label": "/law, govt and politics/politics"
#           },
#           {
#             "score": 0.576106,
#             "label": "/art and entertainment/movies"
#           }
#         ]
#       }
#     }
#   ]
# }

# %%
query_results['results'][0]['enriched_text']
# Out:
# {'sentiment': {'document': {'score': 0, 'label': 'neutral'}},
#  'entities': [{'count': 6,
#    'sentiment': {'score': -0.305738, 'label': 'negative'},
#    'text': 'Han Solo',
#    'relevance': 0.806577,
#    'type': 'Person'},
#   {'count': 1,
#    'sentiment': {'score': 0, 'label': 'neutral'},
#    'text': 'General Hux',
#    'relevance': 0.241239,
#    'type': 'Company'},
#   {'count': 2,
#    'sentiment': {'score': 0, 'label': 'neutral'},
#    'text': 'Ren',
#    'relevance': 0.237616,
#    'type': 'Person'}],
#  'concepts': [{'text': 'Star Wars Episode IV: A New Hope',
#    'relevance': 0.989689,
#    'dbpedia_resource': 'http://dbpedia.org/resource/Star_Wars_Episode_IV:_A_New_Hope'},
#   {'text': 'Obi-Wan Kenobi',
#    'relevance': 0.968787,
#    'dbpedia_resource': 'http://dbpedia.org/resource/Obi-Wan_Kenobi'},
#   {'text': 'Wookiee',
#    'relevance': 0.892406,
#    'dbpedia_resource': 'http://dbpedia.org/resource/Wookiee'},
#   {'text': 'Chewbacca',
#    'relevance': 0.880598,
#    'dbpedia_resource': 'http://dbpedia.org/resource/Chewbacca'},
#   {'text': 'Darth Vader',
#    'relevance': 0.870146,
#    'dbpedia_resource': 'http://dbpedia.org/resource/Darth_Vader'},
#   {'text': 'Han Solo',
#    'relevance': 0.849411,
#    'dbpedia_resource': 'http://dbpedia.org/resource/Han_Solo'},
#   {'text': 'R2-D2',
#    'relevance': 0.848201,
#    'dbpedia_resource': 'http://dbpedia.org/resource/R2-D2'},
#   {'text': 'Rebel Alliance',
#    'relevance': 0.816558,
#    'dbpedia_resource': 'http://dbpedia.org/resource/Rebel_Alliance'}],
#  'categories': [{'score': 0.78683, 'label': '/travel/transports'},
#   {'score': 0.762619, 'label': '/travel/transports/sea travel'},
#   {'score': 0.661241, 'label': '/society/unrest and war'}]}

# %% [markdown]
# ### Process returned results
#
# If you properly structure the query, Watson is able to do a pretty good job of finding the relevant information. But the result returned is a JSON object. Now your task is to convert that result into an appropriate response that best addresses the original natural language question that was asked.
#
# E.g. if the question was "Who saved Han Solo from Jabba the Hutt?" the answer should ideally just be "The Rebels" and not the entire paragraph describing Han Solo's rescue. But that can be a backup response if you cannot be more specific.
#
# _**Note**: You may have to go back to the previous step and modify the query, especially what you want the Discovery service to return, and this may depend on the intent / dialog node triggered. E.g. study the different parts of a "relation" structure to see how you might construct queries to match them._

# %%
# TODO: Process returned results and compose an appropriate response
for contents in query_results['results']:
    for entity in contents['enriched_text']['entities']:
        if entity['type'] == 'JobTitle':
            results = assistant.message(workspace_id=wrk_id,
                            input={'text': question}, context=entity).get_result()

# %% [markdown]
# ## 5. Reflections
#
# **Q**: Now that you have gone through this exercise of designing a system that uses two IBM Watson services, what did you learn? What were some of the strengths and weaknesses of this approach?
#
# **A**: It can only answer for what they already know
#
#
# ## (Optional) Extensions
#
# We have provided a set of sample data files containing Star Wars plot summaries. But as mentioned before, you are free to use your own dataset. In fact, a larger dataset maybe more suitable for use with IBM Watson's NLP services. If you used your own dataset, answer the following questions.
#
# **Q**: What dataset did you use, and in what ways is it different from the sample files provided?
#
# **A**:
#
#
# **Q**: Either include your dataset in the .zip file or repository you submit, or provide clear instructions on how to obtain the dataset, so that your reviewer can run your notebook or inspect the data to verify your results.
#
# **A**:
#
#
# _You can also design a web-based application that utilizes these services and deploy that on Bluemix! If you do, please share with your instructors and peers._
